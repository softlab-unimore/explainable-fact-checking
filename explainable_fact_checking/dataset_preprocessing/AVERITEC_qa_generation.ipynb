# %% [markdown]
# # AVERITEC QA Generation

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import copy

os.chdir('/homes/bussotti/XFC2/code')
print(f'Current working directory: {os.getcwd()}')
from explainable_fact_checking.result_presentation.notebook_utility import *
import json
from tqdm import tqdm

from explainable_fact_checking.dataset_preprocessing.pre import preprocess_AVERITEC
import itertools
# Out:
# Current working directory: /homes/bussotti/XFC2/code
# /home/bussotti/.conda/envs/feverous2/bin/python

# %%
ds_path = os.path.join(xfc.experiment_definitions.C.DATASET_DIR_V2, 'AVERITEC')
preprocessed_path = os.path.join(ds_path, 'preprocessed')
os.makedirs(preprocessed_path, exist_ok=True)
files = ['train', 'dev', 'test']
datasets = {}
for f in files:
    t_name = f
    with open(os.path.join(preprocessed_path, t_name + '.json'), 'r') as f_in:
        datasets[f] = json.load(f_in)

# %%
try:
    with open(os.path.join(preprocessed_path, 'dev_with_genqa.json'), 'r') as f_in:
        dataset_with_genqa = json.load(f_in)
except FileNotFoundError:
    dataset_with_genqa = []
    
for x in dataset_with_genqa:
    print(f'ID: {x["id"]} | LABEL: >{x["label"]}< \nCLAIM: {x["claim"]}')
    for i, ev in enumerate(x[xfc.C.EV_KEY]):
        gold_or_gen = '***Gold***' if x['gold_evidence'][i] == 1 else 'Generated'
        print(f'>>> {ev} [{gold_or_gen}]')
    print()
# Out:
# ID: 0 | LABEL: >Refuted<
# CLAIM: In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.
# >>> Where was the claim first published? It was first published on Sccopertino [***Gold***]
# >>> What did Sean Connery say in his letter to Steve Jobs? In the letter, Connery stated that he was not interested in participating in the commercial. [Generated]
# >>> Was Sean Connery known for participating in commercials before this incident? No. Sean Connery had a reputation for avoiding commercial endorsements throughout his career. [Generated]
# >>> What did Steve Jobs say about celebrity endorsements in general? Steve Jobs was known to appreciate celebrity endorsements but also valued authenticity in marketing. [Generated]
# >>> What kind of website is Scoopertino? Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page [***Gold***]
# >>> Did Sean Connery publicly express his reasons for refusing the commercial? No. There are no public statements from Connery detailing his reasons for the refusal. [Generated]
# >>> What was the general public's reaction to Sean Connery's refusal to appear in commercials? Many fans respected his decision to avoid commercial endorsements, valuing his artistic integrity. [Generated]
#
# ID: 1 | LABEL: >Refuted<
# CLAIM: Trump Administration claimed songwriter Billie Eilish Is Destroying Our Country In Leaked Documents
# >>> Is there evidence that the Trump Administration took action against Billie Eilish? No. There are no records of any official actions taken against her by the administration. [Generated]
# >>> What do critics say about the claims made in the leaked documents? Critics argue that the claims are exaggerated and lack substantial evidence. [Generated]
# >>> Has the Trump administration voiced that Billie Eilish was destroying the country? A Washington Post story wrongly claimed the Trump administration accused Billie Eilish of “destroying our country [***Gold***]
# >>> Did the Trump Administration specifically mention Billie Eilish in their documents? Yes. The leaked documents explicitly reference Billie Eilish as part of their claims. [Generated]
# >>> What was the general sentiment expressed in the leaked documents regarding cultural figures? The documents reflect a critical view of cultural figures influencing public opinion negatively. [Generated]
# >>> What did the leaked documents say about the impact of Billie Eilish's music? The documents stated that her music was seen as contributing to societal issues, according to a source. [Generated]
#
# ID: 2 | LABEL: >Refuted<
# CLAIM: Due to Imran Khan's criticism of Macron's comments on Islam, French authorities cancelled the visas of 183 Pakistani citizens and deported 118 from the country.
# >>> How did Macron criticise Islam? Macron described Islam as a religion “in crisis” worldwide and vowed to present a bill in December to strengthen a law that officially separated church and state in France. [***Gold***]
# >>> What did some sources say about the reasons behind the visa cancellations? Some sources suggest that the visa cancellations were linked to political tensions rather than individual actions. [Generated]
# >>> Were any Pakistani citizens deported from France following the incident? Yes. Reports indicate that 118 Pakistani citizens were deported from France. [Generated]
# >>> Has France cancelled Pakistani citizens' visas? No answer could be found. [***Gold***]
# >>> Who tweeted the original claim? They were tweeted by @PakConsulateFr, which is not Pakistani Consulate of France official Twitter account. [***Gold***]
# >>> How many Pakistani citizens were reported to have their visas cancelled by French authorities? 183 Pakistani citizens had their visas cancelled according to reports. [Generated]
# >>> How did Imran Khan criticise Macron? It is unfortunate that he has chosen to encourage Islamophobia by attacking Islam rather than the terrorists who carry out violence, be it Muslims, White Supremacists or Nazi ideologists. Sadly, President Macron has chosen to deliberately provoke Muslims, incl his own citizens, through encouraging the display of blasphemous cartoons targeting Islam & our Prophet PBUH. By attacking Islam,  clearly without having any understanding of it, President Macron has attacked & hurt the sentiments of millions of Muslims in Europe & across the world [***Gold***]
# >>> Has France deported any Pakistanis due to Khan's comments? No answer could be found. [***Gold***]
# >>> Did Imran Khan publicly criticize Macron's comments on Islam? Yes. Imran Khan made statements regarding Macron's comments during a press conference. [Generated]
# >>> What was the reaction of the French authorities to the criticism from Imran Khan? The French authorities took actions that included visa cancellations and deportations of Pakistani citizens. [Generated]
#
# ID: 3 | LABEL: >Refuted<
# CLAIM: UNESCO declared Nadar community as the most ancient race in the world.
# >>> What is Nadar? Nadar (also referred as Nadan, Shanar) is a caste of Tamil Nadu & Kerala, South India. The Nadars are an entrepreneurial south Indian caste] and constitute 12% of Tamil Nadu's population. The Nadar community was not a singular caste, but an assortment of sub-castes and classes of different origins, which in course of time, came under the single banner Nadar. Nadars are predominant in the southern districts of Tuticorin, Kaniyakumari, Tirunelveli and Virudhunagar. [***Gold***]
# >>> What criteria does UNESCO use to declare a community as ancient? UNESCO typically considers historical significance, cultural heritage, and contributions to civilization when making such declarations. [Generated]
# >>> What are some claims made about the Nadar community's origins? Some sources claim that the Nadar community has roots that trace back several centuries, but the exact timeline is debated. [Generated]
# >>> Did UNESCO officially recognize the Nadar community as an ancient race? Yes. UNESCO has made various declarations regarding cultural heritage, but specific recognition of the Nadar community as the most ancient race is not widely documented. [Generated]
# >>> What did a UNESCO representative say about the Nadar community? A UNESCO representative mentioned that the Nadar community has a rich cultural history, but did not specifically label them as the most ancient race. [Generated]
# >>> What is the world's most ancient race according to UNESCO? No answer could be found. [***Gold***]
# >>> What is the world's most ancient race? The San people of southern Africa, who have lived as hunter-gatherers for thousands of years, are likely to be the oldest population of humans on Earth, according to the biggest and most detailed analysis of African DNA. [***Gold***]
# >>> Is there any evidence that the Nadar community has been recognized in other historical contexts? Yes. The Nadar community has been mentioned in various historical texts, but not necessarily as the most ancient race. [Generated]
#
# ID: 4 | LABEL: >Refuted<
# CLAIM: Republican Matt Gaetz was part of a company that had to pay 75 million in hospice fraud. They stole from dying people.
# >>> Did Matt Gaetz work for Chemed Corporation, Vitas Hospice Services LLC or Vitas Healthcare Corporation? No answer could be found. [***Gold***]
# >>> Did any legal actions result from the hospice fraud allegations? Yes. Legal actions were taken against the company for the fraud allegations. [Generated]
# >>> Was Matt Gaetz directly involved in the hospice fraud case? No. There is no direct evidence linking Matt Gaetz to the fraudulent activities of the company. [Generated]
# >>> What year did Don Gaetz sell Vitas to Chemed? In 2004, VITAS was acquired by Roto Rooter's parent company Chemed for $400 million. [***Gold***]
# >>> Was Chemed Corporation involved in a $75m Fraud charge? Yes : The lawsuit against the company was filed in 2013 — nine years after Don Gaetz sold the company to Chemed in 2004. It’s true that at least some of the instances were alleged to have occurred before that sale date (dating back to 2002), but it’s worth noting that Don Gaetz was not a party to the lawsuit. At the time of the lawsuit’s filing, he denied that the matters in the complaint related to his work with Vitas. [***Gold***]
# >>> What type of patients were affected by the alleged fraud? The alleged fraud primarily affected dying patients in hospice care. [Generated]
# >>> Did Matt Gaetz's father Don Gaetz co-found Vitas? Gaetz is the retired co-founder of VITAS Healthcare Corp., a hospice care provider that comforts patients and their families and preserves their dignity in the face of terminal illness. He was also president of the National Hospice Organization. [***Gold***]
# >>> What was the total amount that the company was ordered to pay in the hospice fraud case? The company was ordered to pay 75 million dollars. [Generated]
# >>> How have critics described the actions of the company involved in the hospice fraud? Critics have described the actions as exploitative and unethical, targeting vulnerable individuals. [Generated]
#
# ID: 5 | LABEL: >Refuted<
# CLAIM: The United States of America and its Western allies have been using their media outlets to publish articles based on fabricated information under allegations of non-compliance with the Chemical Weapons Convention.
# >>> Is there evidence that the United States has used media to influence public perception regarding chemical weapons? Yes. There are instances where the U.S. government has utilized media campaigns to shape narratives. [Generated]
# >>> What have analysts said about the motivations behind the publication of articles on chemical weapons? Analysts suggest that geopolitical interests may drive the publication of such articles, often questioning their objectivity. [Generated]
# >>> Has Syria complied with the Chemical Weapons Convention? No. “Our research shows what Syrians on the ground have known for years: that chemical weapons have become a completely normalised component of the Syrian regime arsenal used for years in full view of the international community with near impunity,” [***Gold***]
# >>> Have any media outlets been accused of publishing fabricated information regarding chemical weapons? Yes. Several media outlets have faced accusations of spreading misinformation about chemical weapons. [Generated]
# >>> What do some reports suggest about the compliance of certain countries with the Chemical Weapons Convention? Reports indicate that there are ongoing concerns about compliance among various nations. [Generated]
# >>> What did a recent article state about the allegations against the United States and its allies? The article claimed that the allegations were based on unverified sources and lacked substantial evidence. [Generated]
#
# ID: 6 | LABEL: >Supported<
# CLAIM: More than 225,000 people dead, 225,000. The estimates are, if we’d have acted responsibly, there’d be 160,000 fewer dead than there are today, because of covid-19.
# >>> How many deaths were recorded in the US on October 31, 2020? 230,512 [***Gold***]
# >>> What is the estimated reduction in deaths if responsible actions had been taken according to the claim? The claim suggests that there would be 160,000 fewer deaths if actions had been taken responsibly. [Generated]
# >>> What does the claim suggest about the responsibility of actions taken during the pandemic? The claim implies that acting responsibly could have significantly reduced the death toll from COVID-19. [Generated]
# >>> Is the number of deaths attributed to COVID-19 mentioned in the claim? Yes. The claim explicitly states that more than 225,000 people have died. [Generated]
# >>> What specific number of deaths does the claim state? The claim states that more than 225,000 people are dead due to COVID-19. [Generated]
# >>> Would a faster COVID response in the US reduced the death toll? Due to exponential viral spread, our delay in action was devastating. In the wake of the U.S. response, 117,858 Americans died in the four months following the first 15 confirmed cases. After an equivalent period, Germany suffered only 8,863 casualties. Scaling up the German population of 83.7 million to America’s 331 million, a U.S.-sized Germany would have suffered 35,049 Covid-19 deaths. So if the U.S. had acted as effectively as Germany, 70% of U.S. coronavirus deaths might have been prevented. [***Gold***]
# >>> What is 70% of 230,512? 161,358 [***Gold***]
# >>> Did the claim imply that government actions could have changed the death toll? Yes. The claim suggests that responsible actions could have led to fewer deaths. [Generated]
#
# ID: 7 | LABEL: >Supported<
# CLAIM: Why should you pay more taxes than Donald Trump pays? And that’s a fact. $750. Remember what he said when that was raised a while ago, how he only pays … He said, ‘Because I’m smart. I know how to game the system.’
# >>> What was Trump's tax return in 2017? Trump Paid $750 in Federal Income Taxes in 2017 [***Gold***]
# >>> Is it true that many Americans feel they pay more taxes than wealthy individuals like Donald Trump? Yes. Surveys indicate that a significant portion of the population believes the tax system is unfair. [Generated]
# >>> What do critics say about the fairness of the tax system in relation to wealthy individuals? Critics argue that the tax system allows wealthy individuals to exploit loopholes, leading to lower tax payments. [Generated]
# >>> What was the exact quote from Donald Trump regarding his tax strategy? He said, ‘Because I’m smart. I know how to game the system.’ [Generated]
# >>> When did Trump say he was smart for not paying taxes? He made the boast during the 2016 electoral debate with Hilary Clinton [***Gold***]
# >>> Did Donald Trump pay only $750 in federal income taxes for the year 2016? Yes. This amount was reported in various news articles discussing Trump's tax returns. [Generated]
# >>> What did Donald Trump imply about his tax payments in relation to his intelligence? He suggested that he pays less because he is smart and knows how to navigate the tax system. [Generated]
#
# ID: 8 | LABEL: >Refuted<
# CLAIM: You’re watching the cheaters and all those people that send in the phony ballots. … They want to have the count weeks after November 3.
# >>> When are mail-in ballots counted? Vote-by-mail ballots that are mailed must be postmarked on or before Election Day and received by your county elections office no later than 7 days after Election Day. [***Gold***]
# >>> Is there evidence that the counting of ballots will take weeks after November 3? No. Most states have laws requiring ballots to be counted by a certain deadline. [Generated]
# >>> What do critics say about the timing of ballot counting? Critics argue that extended counting periods could lead to confusion and mistrust in the electoral process. [Generated]
# >>> What did a local election official say about ballot counting procedures? The official stated, 'We will ensure that every legitimate vote is counted as soon as possible.' [Generated]
# >>> are all non-mail ballots counted by election day? No. The counting will take time and is not done by the end of election day. [***Gold***]
# >>> Are there reports of people submitting fraudulent ballots? Yes. There have been isolated incidents reported, but they are not widespread. [Generated]
# >>> What is the general timeline for counting ballots in elections? Ballots are typically counted on election night, but some states allow counting to continue for days after the election. [Generated]
#
# ID: 9 | LABEL: >Not Enough Evidence<
# CLAIM: You see the number today? 33.1 GDP. The biggest in the history of our country by almost triple, right? Almost triple. Now it’s very much bigger than any GDP we’ve ever had. You have to go back to the 1950s, and then it’s less than half. This is the greatest number, 33.1 percent.
# >>> Was 1950's U.S GDP less than half of 2020's GDP of 33.1? Yes. 28.1 percent in 1953 [***Gold***]
# >>> Has the GDP ever been reported to be less than half of the current figure in the past? Yes. The claim indicates that previous GDP figures were less than half of the current 33.1%. [Generated]
# >>> What is the significance of the number 33.1% according to the speaker? The speaker claims it is the greatest number ever recorded for GDP growth. [Generated]
# >>> What does the speaker imply about the GDP growth compared to previous records? The speaker suggests that the current GDP is almost triple the previous highest records. [Generated]
# >>> What was the USA's GDP in the 1950s? No answer could be found. [***Gold***]
# >>> Is 33.1% the highest GDP growth rate recorded in the country? Yes. The claim states that 33.1% is the biggest GDP number in the history of the country. [Generated]
# >>> What historical period does the claim reference for comparison to the current GDP? The 1950s [Generated]
#
# ID: 10 | LABEL: >Conflicting Evidence/Cherrypicking<
# CLAIM: Donald Trump, when he thinks of climate change, he says hoax. Well, guess what? Speaking of hoaxes, remember what he said about these increasing violent hurricanes and the frequency? He actually said, maybe we should detonate a nuclear bomb over the Atlantic. By the way, the same stable genius who said the biggest problem we had in the Revolutionary War is we didn’t have enough airports.
# >>> Did Trump ever suggest bombing hurricanes to prevent them from reaching the US? Trump suggested nuking hurricanes to stop them from hitting U.S [***Gold***]
# >>> Has Trump made controversial statements about natural disasters? Yes. Trump has made several controversial statements regarding natural disasters, including hurricanes. [Generated]
# >>> What is the general perception of Trump's comments on climate change? Many view his comments as dismissive and lacking scientific basis. [Generated]
# >>> What did Trump say about airports during the Revolutionary War? He claimed that the biggest problem in the Revolutionary War was the lack of airports. [Generated]
# >>> Did Donald J. Trump say; ''biggest problem we had in the Revolutionary War is we didn’t have enough airports''? He did speak of the congressional army taking all of the airports over, however there were no airports at the time. However he blamed his teleprompter. [***Gold***]
# >>> Did Donald Trump refer to climate change as a hoax? Yes. Donald Trump has publicly stated that he believes climate change is a hoax. [Generated]
# >>> What did Trump suggest regarding hurricanes and nuclear bombs? He suggested that maybe we should detonate a nuclear bomb over the Atlantic to disrupt hurricanes. [Generated]
#
# ID: 11 | LABEL: >Conflicting Evidence/Cherrypicking<
# CLAIM: The U.S. surgeon general and the Centers for Disease Control both previously said that ‘masks are not effective in preventing [the] general public from catching coronavirus.’
# >>> Have there been any updates from health authorities regarding mask effectiveness since the initial statements? Yes. Health authorities have updated their guidance on mask effectiveness as new evidence emerged. [Generated]
# >>> What do some experts say about the role of masks in controlling the spread of respiratory viruses? Some experts argue that masks can help reduce the transmission of respiratory viruses, including coronavirus, especially in crowded settings. [Generated]
# >>> Are masks effective in preventing people from catching coronavirus? The effectiveness of face masks is dependent on how they are used. Face mask use was 79% effective in reducing transmission in certain situations. But not effective in certain other situations. [***Gold***]
# >>> Did the U.S. surgeon general make a statement about the effectiveness of masks? Yes. The U.S. surgeon general has publicly commented on the effectiveness of masks in various contexts. [Generated]
# >>> What was the general sentiment expressed by health officials regarding mask usage during the pandemic? Health officials expressed mixed messages about mask usage, indicating that they may not be effective for everyone. [Generated]
# >>> What did the CDC say about masks in relation to the general public and coronavirus? The CDC stated that masks are not a guaranteed method to prevent the spread of coronavirus among the general public. [Generated]
#
# ID: 12 | LABEL: >Refuted<
# CLAIM: New Zealand’s new Food Bill bans gardening
# >>> Which Food Bill does the claim refer to? The claim refers to the Food Act 2014, first read in New Zealand Parliament in May 2010. [***Gold***]
# >>> What has been the public reaction to the Food Bill's proposed regulations? Public reaction has been mixed, with some supporting the regulations for safety and others fearing overreach. [Generated]
# >>> Have any local gardeners expressed concerns about the Food Bill? Yes. Many local gardeners have voiced their worries about potential impacts on gardening practices. [Generated]
# >>> What is the date of the blog post? The date on the post is October 29, 2020 [***Gold***]
# >>> What did the New Zealand Food Safety Minister say about the Bill on 12 October, 2011? The new Food Bill is about modernising legislation that is now 30 years old. It is about ensuring that people who sell and prepare food do so safely. [***Gold***]
# >>> What does the Food Bill say about community gardens? The Food Bill does not provide specific guidelines regarding community gardens, leaving their status ambiguous. [Generated]
# >>> Does the blog post imply that this Food Bill is already legislation? No. The blog text uses future terminology like "...the bill is being brought in..." and "...this NZ food bill will pave the way...".The title of the blog refers to the Food Bill as "New Food Bill in New Zealand..."This bill would on commencement replace the Food Act 1981 and over time the Food Hygiene Regulations 1974 and the Food (Safety) Regulations 2002. [***Gold***]
# >>> What amendments have been made to the Act up to the claim date? Public Service Act 2020 (2020 No 40): section 135 Education and Training Act 2020 (2020 No 38): section 668 Privacy Act 2020 (2020 No 31): section 217 COVID-19 Response (Further Management Measures) Legislation Act 2020 (2020 No 13): section 3 Statutes Amendment Act 2019 (2019 No 56): Part 18 Customs and Excise Act 2018 (2018 No 4): section 443(3) Food Safety Law Reform Act 2018 (2018 No 3): Part 1 District Court Act 2016 (2016 No 49): section 261 Senior Courts Act 2016 (2016 No 48): section 183(b), (c) Food Regulations 2015 (LI 2015/310): Schedule 1 clause 7 Legislation (Confirmable Instruments) Amendment Act 2015 (2015 No 120): section 14 [***Gold***]
# >>> Does the Food Bill specifically mention restrictions on home gardening? No. The text of the Food Bill does not explicitly state that home gardening is banned. [Generated]
# >>> What are some of the main objectives of New Zealand's new Food Bill? The Food Bill aims to improve food safety and ensure better regulation of food production. [Generated]
#
# ID: 13 | LABEL: >Supported<
# CLAIM: Wearing face masks will stop the spread of covid 19
# >>> Is it true that all types of masks provide the same level of protection against covid-19? No. Different types of masks offer varying levels of protection, with N95 masks providing more than cloth masks. [Generated]
# >>> What have studies indicated about mask-wearing and covid-19 transmission rates? Studies have indicated that areas with mask mandates saw a decrease in covid-19 transmission rates. [Generated]
# >>> Does a face mask prevent the spread of Covid 19? Cloth face coverings, even homemade masks made of the correct material, are effective in reducing the spread of COVID-19 - for the wearer and those around them - according to a new study from Oxford’s Leverhulme Centre for Demographic Science. [***Gold***]
# >>> Do face masks completely eliminate the risk of transmitting covid-19? No. While face masks reduce the risk of transmission, they do not eliminate it entirely. [Generated]
# >>> What do health organizations recommend regarding face mask usage? Health organizations recommend wearing face masks in crowded or enclosed spaces to reduce transmission risk. [Generated]
# >>> What did the CDC state about the effectiveness of face masks? The CDC stated that masks are effective in reducing the spread of respiratory droplets. [Generated]
#
# ID: 14 | LABEL: >Refuted<
# CLAIM: Jammu and Kashmir (J&K) in Pakistan/India was removed from the United Nations (UN) list of “unresolved disputes”.
# >>> What is the dispute in Jammu and Kasmir about? The first Indo-Pakistan war, in 1947-1948, split Jammu and Kashmir in two, with both countries since claiming ownership over the entire territory. As such, Kashmir is both the cause and consequence of war and hostilities between the two nuclear-armed states [***Gold***]
# >>> Has there been any recent change in the status of Jammu and Kashmir in international discussions? No. Recent discussions have continued to recognize Jammu and Kashmir as a disputed area. [Generated]
# >>> What do analysts say about the implications of removing Jammu and Kashmir from the UN list? Analysts suggest that removing Jammu and Kashmir from the UN list could lead to increased tensions between India and Pakistan. [Generated]
# >>> What was stated in the latest UN resolution regarding Jammu and Kashmir? The latest UN resolution emphasizes the need for dialogue between India and Pakistan regarding Jammu and Kashmir. [Generated]
# >>> Was Jammu and Kashmir an item on the agenda of the Security Council? “However, the point is Jammu & Kashmir has never been an item on the agenda of the Security Council. It has always been “India-Pakistan question”. Further, since the last formal meeting of the Council on this agenda item also took place in November 1965, even this is listed in a separate category by the Secretary-General in his regular report on the list of items seized by the Council. The India/Pakistan question is listed in a separate category of items which have not been considered in the last 3 years [***Gold***]
# >>> Was Jammu and Kashmir previously listed as an unresolved dispute by the UN? Yes. Jammu and Kashmir has been recognized as a disputed territory by the UN in various resolutions. [Generated]
# >>> What does the UN's list of unresolved disputes typically include? The UN's list includes various territorial disputes that have not been resolved through diplomatic means. [Generated]
#
# ID: 15 | LABEL: >Not Enough Evidence<
# CLAIM: Illegal drug, border crossings, and human smuggling activities have decreased in areas where barriers are deployed in the United States.
# >>> Which border is this claim referring to? The US-Mexico border. [***Gold***]
# >>> What do experts say about the effectiveness of barriers in reducing illegal drug activities? Experts suggest that while barriers can help, they are not a standalone solution and must be part of a broader strategy. [Generated]
# >>> Is there evidence that barriers have completely eliminated illegal activities at the border? No. While barriers may reduce some activities, they have not completely eliminated illegal crossings or smuggling. [Generated]
# >>> How much of the border has barriers as of October 2020? Now, according to US Customs and Border Protection (CBP) in its 6 October status report, the southern border has 669 miles of "primary barrier" - the first structure people heading from Mexico to the US will encounter - and 65 miles of "secondary barrier" - which usually runs behind the primary structure as a further obstacle. This means that in areas where no barricades existed before, they have built 15 miles of new, primary barrier or "border wall system", as it is called by CBP. ​​About a further 350 miles of barrier has been built, according to CBP, made up of replacement structures and some new secondary barrier. More is planned, too, with 378 miles of new and replacement barrier either under construction or in the "pre-construction phase". Less than half of this will be in locations where no barriers currently exist, according to CBP. [***Gold***]
# >>> When did the Covid-19 pandemic emerge? The novel coronavirus (SARS-CoV-2) that causes COVID-19 first emerged in the Chinese city of Wuhan in 2019 and was declared a pandemic by the World Health Organization (WHO) [***Gold***]
# >>> What statistics were provided regarding border crossings in areas with barriers? According to the data, border crossings have decreased by approximately 10% in some areas with barriers. [Generated]
# >>> Did the US-Mexico border have barriers before President Tump took office? Yes. About 654 miles of the 1,991-mile border already had some kind of fabricated barrier when Mr. Trump took office. Much of the rest has natural barriers; approximately 1,295 miles of the border are river, and 696 miles are land.Yes. Before he took office, there were 654 miles (just over 1,000km) of barrier along the southern border - made up of 354 miles of barricades to stop pedestrians and 300 miles of anti-vehicle fencing. [***Gold***]
# >>> How many border encounters were there in 2018-2020? Fiscal years 2018 - 521,090 2019 - 977,509 2020 - 458,088 [***Gold***]
# >>> Have there been any studies indicating a decrease in illegal drug trafficking in areas with barriers? Yes. Several studies have reported a reduction in drug trafficking in regions where barriers are present. [Generated]
# >>> What did a recent report say about human smuggling activities in border areas? The report indicated that human smuggling activities have fluctuated but did not provide a clear trend related to barriers. [Generated]
#
# ID: 16 | LABEL: >Refuted<
# CLAIM: The plentiful evidence we have indicates that masks would not meaningfully help with aerosol transmission of COVID 19.
# >>> Have any studies been done to show if masks help with Aerosol transmission ? Surgical face masks significantly reduced detection of influenza virus RNA in respiratory droplets and coronavirus RNA in aerosols, with a trend toward reduced detection of coronavirus RNA in respiratory droplets. Our results indicate that surgical face masks could prevent transmission of human coronaviruses and influenza viruses from symptomatic individuals. [***Gold***]
# >>> Have any health experts publicly disagreed with the claim that masks do not help with aerosol transmission? Yes. Many health experts have stated that masks are an important tool in reducing transmission. [Generated]
# >>> What is a common argument made by those who believe masks are ineffective against aerosol transmission? Some argue that aerosol particles are too small for masks to filter effectively, thus limiting their usefulness. [Generated]
# >>> What did the World Health Organization say about mask usage during the pandemic? The World Health Organization recommended the use of masks in certain situations to help control the spread of COVID-19. [Generated]
# >>> Do any health body's recommend wearing a facemask to help slow down aerosol transmission of viruses at the time of the claim (2020)? At of claim yes, the (CDC) and the World Health Organization now recommended cloth masks for the general public, but earlier in the pandemic, both organizations recommended just the opposite. [***Gold***]
# >>> Is there evidence that masks are effective against aerosol transmission of viruses in general? Yes. Studies have shown that masks can reduce the transmission of various respiratory viruses, including influenza. [Generated]
# >>> What do some studies suggest about the effectiveness of masks in preventing COVID-19 transmission? Some studies indicate that masks can help reduce the spread of COVID-19, especially in crowded settings. [Generated]
#
# ID: 17 | LABEL: >Refuted<
# CLAIM: All USA Ballots Arriving After Election Day Will Be Thrown Out
# >>> What was the election day in the 2020 US presidential elections? November 3, 2020. [***Gold***]
# >>> Are there any exceptions to the rule about ballots arriving after Election Day? Yes, some states have provisions for ballots that are postmarked by Election Day but arrive late due to postal delays.. Certain states have laws that allow for exceptions based on postmark dates. [Generated]
# >>> Will ballots that arrive after Election Day be counted in any circumstances? No. Election laws in many states specify that ballots must be received by Election Day to be counted. [Generated]
# >>> Was there an extension to the deadline of receipt of mail ballots in the 2020 elections? Yes. Numbered Memorandum 2020-22 (“Memo 2020-22”), the policy at issue in this case, makes two accommodations in light of the COVID-19 pandemic and “[d]ue to current delays with mail sent with the U.S. Postal Service.” Memo 2020-22, at 1. First, it extends the deadline by which timely mailed ballots must be received in order to be counted from three days after Election Day to nine days; and, second, it expands the mechanisms by which officials can determine the date on which an absentee ballot was mailed. Memo 2020-22, at 1. [***Gold***]
# >>> What was the deadline for receipt of mail ballots in Alaska and Maryland in the 2020 US presidential elections? Absentee ballots must be postmarked by Nov. 3 and received by Nov. 13. [***Gold***]
# >>> What have election officials said about the handling of late ballots? Election officials have indicated that they will follow state laws regarding the counting of late ballots, which may vary by state. [Generated]
# >>> When was the deadline to receiving votes by mail? Your mail-in ballot must be mailed or dropped in a drop off box location location by 8 pm on Election Day, November 3. If you mail your ballot, it must be postmarked on or before November 3, 2020 to be counted. [***Gold***]
# >>> What do some states say about mail-in ballots and their deadlines? Some states allow mail-in ballots to be counted if they are postmarked by Election Day and received within a certain timeframe. [Generated]
# >>> What does the law state regarding ballots received after Election Day? According to the law, ballots received after Election Day are generally not counted unless specific conditions are met. [Generated]
#
# ID: 18 | LABEL: >Conflicting Evidence/Cherrypicking<
# CLAIM: Even if your mail-in ballot is postmarked prior to the Election day but arrives after the Election day it will be thrown out.
# >>> Do some states accept ballots that were postmarked before election day? There are 22 states plus the District of Columbia [***Gold***]
# >>> What do election officials say about the handling of mail-in ballots that arrive late? Election officials have stated that ballots received after Election Day are typically not counted, regardless of the postmark date. [Generated]
# >>> What have some states implemented regarding mail-in ballot deadlines? Some states have implemented laws that allow ballots postmarked by Election Day to be counted if they arrive within a certain timeframe after the election. [Generated]
# >>> Is it true that mail-in ballots must be received by Election Day to be counted? Yes. Many states require that mail-in ballots be received by Election Day to ensure they are counted. [Generated]
# >>> What does the law say about the postmark date of mail-in ballots? According to the law, ballots must be postmarked by Election Day to be considered valid, but this does not guarantee they will be counted if they arrive late. [Generated]
# >>> Are there states which do require votes to arrive by election day.? Wisconsin is one of about 30 states that require absentee ballots be received by Election Day to be counted. [***Gold***]
# >>> Does the original posterLiz Gilbert mention the state that does not allow voting after deadline? No. Even if your mail-in ballot is postmarked today, if it arrives after Election Day, it will be thrown out. Discounted. Ignored. (Thanks, Supreme Court. Thanks, GOP. [***Gold***]
# >>> Are there any exceptions to the rule about counting late mail-in ballots? No. Generally, there are no exceptions for counting mail-in ballots that arrive after Election Day. [Generated]
#
# ID: 19 | LABEL: >Refuted<
# CLAIM: Video shows attack of French embassy in Sudan
# >>> When was the video taken? The video was taken on 14th September 2012 [***Gold***]
# >>> Were there any casualties reported during the attack on the French embassy? Yes. Reports indicated that there were injuries among the embassy staff during the attack. [Generated]
# >>> How has the international community reacted to the attack on the French embassy in Sudan? The international community has expressed concern over the safety of diplomatic missions in conflict zones. [Generated]
# >>> What did the official statement from the French government say regarding the embassy attack? The French government stated that they were investigating the incident and ensuring the safety of their personnel. [Generated]
# >>> Which embassy was being attacked in the video? In Sudan, demonstrators stormed the German embassy and set it on fire in a bloody protest against an Islam-critical abusive video [***Gold***]
# >>> Was there any prior warning about the attack on the French embassy in Sudan? No. There were no credible reports indicating that a warning was issued before the attack. [Generated]
# >>> What did eyewitnesses report about the events at the French embassy? Eyewitnesses described chaotic scenes with people shouting and running away from the embassy area. [Generated]
#
# ID: 20 | LABEL: >Refuted<
# CLAIM: Viral video purportedly shows Pakistani opposition MPs chanted ‘Modi, Modi’ (India's PM)  inside the Pakistani Parliament
# >>> Are there any official statements from the Pakistani government regarding the video? No. There have been no official statements from the government addressing the video. [Generated]
# >>> What reactions have been observed on social media regarding the video? Social media reactions have been mixed, with some users expressing outrage and others dismissing it as fake news. [Generated]
# >>> Were there any reports of the event in the pakistani parliament? A detailed report of the proceedings are detailed in a report in the Dawn, there is no mention of people shouting Modi Modi. But people did shout 'voting, voting' [***Gold***]
# >>> Did the video show any specific individuals chanting in the Parliament? No. The video does not clearly identify any specific individuals who were chanting. [Generated]
# >>> What was the context in which the chant ‘Modi, Modi’ was reportedly made? The chant was allegedly made during a heated debate in the Parliament. [Generated]
# >>> What did a local news outlet report about the incident? A local news outlet reported that the video was edited and taken out of context. [Generated]
#
# ID: 21 | LABEL: >Refuted<
# CLAIM: Taylor Zundel claimed on Instagram that she and other early voters in Utah, were unable to cast ballots in the 2020 presidential elections, as they were told they had already voted.
# >>> Was there any official response from election authorities regarding the claims made by Zundel? No. There has been no documented response from election officials addressing Zundel's claims. [Generated]
# >>> What platform did Taylor Zundel use to share her voting experience? She shared her experience on Instagram. [Generated]
# >>> Was Utah resident Taylor Zundel able to vote in the 2020 presidential elections? Yes. Election officials cleared her vote after a technical problem with her voter card. [***Gold***]
# >>> Did Taylor Zundel specifically mention her voting experience on Instagram? Yes. Taylor Zundel's Instagram post directly references her experience as an early voter. [Generated]
# >>> What issue did early voters in Utah face during the 2020 presidential elections according to the claim? Early voters were reportedly told they had already voted, preventing them from casting their ballots. [Generated]
# >>> What does the claim say about the timing of the voting issue? The issue occurred during the 2020 presidential elections. [Generated]
#
# ID: 22 | LABEL: >Refuted<
# CLAIM: Trash Can Plastered With 'Ballot Box' Sign In Philadelphia Was Intended To Get People To Toss Their Ballots In The Trash.
# >>> Did any officials investigate the incident involving the trash can? No. There have been no reports of an official investigation into the trash can incident. [Generated]
# >>> What do some community members believe about the purpose of the sign? Some community members believe the sign was intended as a prank to mislead voters. [Generated]
# >>> Did a worker in Philadelphia mark the trash cans so that people would throw away their ballots? The posters proclaiming Ballot Box on sidewalk solar-powered trash compactors were created to advertise Ballot Box an exhibit and not to throw votes in the trash. [***Gold***]
# >>> Was the trash can actually labeled with a 'Ballot Box' sign? Yes. Witnesses reported seeing a trash can with a 'Ballot Box' sign attached. [Generated]
# >>> What was the public's reaction to the trash can with the 'Ballot Box' sign? Many people expressed confusion and concern over the sign's intent. [Generated]
# >>> What did a local news report say about the incident? A local news report stated that the sign was placed on the trash can during a busy voting period. [Generated]
#
# ID: 23 | LABEL: >Refuted<
# CLAIM: Joe Biden wants to ban fracking
# >>> Did Joe Biden ever support fracking in the past? Yes. In the past, Joe Biden has expressed support for fracking as a means to promote energy independence. [Generated]
# >>> What do analysts say about the implications of Biden's energy policies? Analysts suggest that his energy policies could lead to a significant reduction in fracking activities if fully implemented. [Generated]
# >>> What is Joe Bidens stance on fracking? hes never said he opposes it. [***Gold***]
# >>> Has Joe Biden publicly stated his position on fracking? Yes. Joe Biden has made public statements regarding his stance on fracking during his campaign. [Generated]
# >>> What did Joe Biden say about fracking during the presidential debates? During the debates, he mentioned that he would transition away from fossil fuels, which includes fracking. [Generated]
# >>> What specific actions has Joe Biden proposed regarding fossil fuel extraction? He has proposed a plan to reduce fossil fuel extraction on public lands, which could impact fracking operations. [Generated]
#
# ID: 24 | LABEL: >Refuted<
# CLAIM: Germany’s Foreign Minister Heiko Maas said that Thailand’s King Maha Vajiralongkorn didn’t do anything illegal while at his German residence.
# >>> What is Thailand’s King Maha Vajiralongkorn accused of doing while at his German residence? He is accused of conducting politics from the European country, where he spends much of his time. [***Gold***]
# >>> What was the context of Heiko Maas's statement about the King? Heiko Maas's statement was made in relation to the King's activities while residing in Germany. [Generated]
# >>> What do analysts say about the implications of Maas's statement on international relations? Analysts suggest that Maas's statement could impact Germany's diplomatic relations with Thailand. [Generated]
# >>> Did Heiko Maas make a statement regarding King Maha Vajiralongkorn's actions? Yes. Heiko Maas is quoted as having made a statement about King Maha Vajiralongkorn. [Generated]
# >>> What did Heiko Maas specifically say about the legality of the King's actions? Heiko Maas stated that the King didn’t do anything illegal. [Generated]
# >>> Has Germany’s Foreign Minister Heiko Maas made any comments on Thailand’s King Maha Vajiralongkorn conducting business within Germany? Maas told parliament. "We have made it clear that politics concerning Thailand should not be conducted from German soil," [***Gold***]
# >>> Did Germany’s Foreign Minister Heiko Maas say that the king has done nothing illegal? No. German Foreign Minister Heiko Maas: 'I am also watching what the Thai king gets up to in Germany.' [***Gold***]
# >>> Is it true that King Maha Vajiralongkorn has faced legal issues in other countries? Yes. There have been reports of legal issues involving King Maha Vajiralongkorn in other jurisdictions. [Generated]
#
# ID: 25 | LABEL: >Supported<
# CLAIM: McDonald’s Azerbaijan's official account was promoting the military taking of Nagorno-Karabakh.
# >>> Is there any evidence that McDonald's Azerbaijan has a history of political commentary? No. There is no record of McDonald's Azerbaijan engaging in political commentary prior to this incident. [Generated]
# >>> What reactions have been noted regarding McDonald's Azerbaijan's posts about Nagorno-Karabakh? Reactions have been mixed, with some praising the support and others criticizing it. [Generated]
# >>> Was Mc Donald's Azerbaijan official account posting about military stuff? Yes [***Gold***]
# >>> Did McDonald's Azerbaijan's official account post about Nagorno-Karabakh recently? Yes. The official account had a recent post that mentioned Nagorno-Karabakh. [Generated]
# >>> What was the general sentiment expressed in the posts from McDonald's Azerbaijan's account? The posts appeared to support military actions in the region. [Generated]
# >>> What did the official account say about military actions in Nagorno-Karabakh? The account stated, 'We stand with our brave soldiers in the region.' [Generated]
#
# ID: 26 | LABEL: >Not Enough Evidence<
# CLAIM: Ivermectin is a treatment for coronavirus.
# >>> What is ivermectin? Ivermectin is one of the most important antibiotics discovered. [***Gold***]
# >>> Have any clinical trials been conducted to test Ivermectin for COVID-19 treatment? Yes. Several clinical trials have been initiated to evaluate Ivermectin for COVID-19. [Generated]
# >>> What is the primary use of Ivermectin as recognized by health organizations? Ivermectin is primarily used to treat parasitic infections. [Generated]
# >>> What does the World Health Organization say about the use of Ivermectin for COVID-19? The WHO recommends against the use of Ivermectin for COVID-19 outside of clinical trials. [Generated]
# >>> Could invermectin be used as a treatment for Covid-19? The clinical efficacy and utility of ivermectin in SARS CoV-2 infected patients are unpredictable at this stage, as we are dealing with a completely novel virus. We await results of well-designed large scale randomized controlled clinical trials exploring treatment efficacy of ivermectin to treat SARS-CoV-2. [***Gold***]
# >>> Is Ivermectin approved for treating COVID-19 by any health authority? No. The FDA has not approved Ivermectin for treating COVID-19. [Generated]
# >>> What did some studies suggest about Ivermectin's effectiveness against coronavirus? Some studies indicated potential antiviral effects, but results were inconclusive. [Generated]
#
# ID: 27 | LABEL: >Refuted<
# CLAIM: Sleeping under a mosquito bed net treated (or not treated) with insecticide is ineffective and harmful to human health.
# >>> Is sleeping under a mosquito bed net effective? Sleeping under a bed net reduces the risk of man-vector contact as mosquitoes bite at night and is thus an effective preventive measure. [***Gold***]
# >>> Are there any known side effects of using insecticide-treated mosquito nets? Yes. Some studies have reported mild side effects such as skin irritation in sensitive individuals. [Generated]
# >>> What is the general public perception of sleeping under mosquito nets? Many people believe that sleeping under mosquito nets is a safe and effective way to prevent mosquito bites, regardless of treatment. [Generated]
# >>> What did a recent study conclude about the health effects of untreated mosquito nets? The study indicated that untreated mosquito nets may not provide adequate protection against mosquito bites, leading to potential health risks. [Generated]
# >>> Is sleeping under a mosquito bed harmful to human health? Insecticides used for mosquito nets are not harmful to people, if used correctly. Direct skin contact with the insecticide on a still wet net may cause a tingling sensation on the skin. This is not harmful, even for small children. [***Gold***]
# ...
#
# ID: 41 | LABEL: >Refuted<
# CLAIM: Wearing face masks can cause infections from bacteria such as staphylococcus.
# >>> Does wearing face mask cause bacterial infection (staphylococcus ) on your face ? Wearing masks for a long time causes a lot of physiological and psychological loads and can reduce work efficiency. The activity cannot be performed as much or as efficiently while wearing the mask as when the masks are not worn. In addition, when you can continue an activity, it decreases when using the mask. Prolonged use of N95 and surgical masks can cause physical side effects such as acne, difficulty breathing, headaches, impaired cognition, rashes, and skin breakdown. It also interferes with vision, communication, and thermal balance [34]. [***Gold***]
# >>> Is staphylococcus a common bacteria found on the skin? Yes. Staphylococcus is a type of bacteria that is commonly found on human skin. [Generated]
# >>> What precautions are recommended for mask hygiene? Experts recommend washing reusable masks regularly and avoiding touching the inside of the mask to minimize infection risk. [Generated]
# >>> What did a health expert say regarding the risks of wearing face masks? A health expert mentioned that while masks are essential for preventing viral transmission, they should be changed regularly to avoid bacterial buildup. [Generated]
# >>> What cause ‘staph’ infections? You probably come into contact with staph bacteria on a daily basis, but it doesn’t always cause an infection. If you have a break in your skin, though, such as a cut, scrape, or burn, the bacteria can enter your body and cause an infection. There are several things that can cause a a break in the delicate skin inside your nose, including:   excessive nose blowing   picking your nose   plucking or tweezing your nose hairs   having a nose piercing [***Gold***]
# >>> Can wearing face masks lead to bacterial growth in certain conditions? Yes. Face masks can create a warm and moist environment, which may promote bacterial growth. [Generated]
# >>> What do some studies suggest about the relationship between face masks and bacterial infections? Some studies indicate that improper use of face masks can lead to an increase in bacterial colonization. [Generated]
#
# ID: 42 | LABEL: >Supported<
# CLAIM: An 'anti-Black Lives Matter' flag replaced the American flag behind President Trump during a Waukesha campaign rally.
# >>> What flag is seen as an anti Black Lives Matter flag? The Blue Lives Matter Flag is said to have racist symbolism which is anti Black Lives Matter. [***Gold***]
# >>> Did President Trump address the flag during his speech at the rally? No. There is no record of Trump mentioning the flag specifically in his speech. [Generated]
# >>> What has been the general public reaction to the use of such flags at political events? Public reactions have been mixed, with some supporting the display and others condemning it as divisive. [Generated]
# >>> What did a local news outlet report about the rally's atmosphere? The local news outlet reported that the rally had a charged atmosphere with various political symbols. [Generated]
# >>> Did the Blue Lives Matter Flag show at a Donald trump Rally in Waukesha campaign rally in 2020? Yes. A large Blue Lives Matter Flag was behind the podium on which Donald Trump spoke at during the Waukesha rally. [***Gold***]
# >>> Was there any mention of a flag being displayed at the rally? Yes. Reports indicate that flags were present at the rally. [Generated]
# >>> What did some attendees say about the flag that was displayed? Attendees described the flag as a symbol of opposition to the Black Lives Matter movement. [Generated]
#
# ID: 43 | LABEL: >Conflicting Evidence/Cherrypicking<
# CLAIM: Donald Trump said that $15 an hour is too much for essential workers
# >>> Have other politicians expressed differing views on the $15 wage for essential workers? Yes. Several politicians have advocated for a $15 minimum wage, contrasting with Trump's statement. [Generated]
# >>> What do labor organizations say about the proposed wage for essential workers? Labor organizations argue that $15 an hour is a necessary living wage for essential workers. [Generated]
# >>> Did Donald Trump say that $15 an hour is too much for essential workers? Trump Says He’d ‘Consider’ $15 Per Hour Federal Minimum Wage, But Prefers To Leave It To States [***Gold***]
# >>> Did Donald Trump make a statement regarding the wage for essential workers? Yes. There are multiple reports confirming that Donald Trump made comments about wages for essential workers. [Generated]
# >>> What was the context in which Donald Trump discussed the wage for essential workers? Trump's comments were made during a press conference addressing economic recovery efforts. [Generated]
# >>> What specific amount did Donald Trump mention in relation to essential workers' wages? He mentioned that $15 an hour is too much for essential workers. [Generated]
#
# ID: 44 | LABEL: >Refuted<
# CLAIM: Deliberately infecting children to COVID-19 at “pox parties” could be a good way to help create herd immunity against COVID-19 without a vaccine.
# >>> Are pox parties recommended by the CDC? CDC strongly recommends against hosting or participating in these events [***Gold***]
# >>> What do health experts say about the effectiveness of natural infection for herd immunity? Health experts generally caution against relying on natural infection for herd immunity due to potential risks. [Generated]
# >>> What are some potential consequences of deliberately infecting children with COVID-19? Potential consequences include severe illness, long-term health effects, and increased transmission rates. [Generated]
# >>> Is there evidence that pox parties have been used historically for other diseases? Yes. Pox parties were historically used to spread chickenpox among children to promote immunity. [Generated]
# >>> What did a recent study conclude about the safety of intentionally infecting children with COVID-19? The study concluded that intentionally infecting children with COVID-19 poses significant health risks and is not advisable. [Generated]
# >>> What are the adverse effects of infecting children with COVID-19? A complication that has more recently been observed in children can be severe and dangerous. Called multisystem inflammatory syndrome in children (MIS-C), it can lead to life-threatening problems with the heart and other organs in the body. Early reports compare it to Kawasaki disease, an inflammatory illness that can lead to heart problems [***Gold***]
# >>> Is herd immunity a risk worth taking? Scientists refer to herd immunity as a dangerous fallacy that is unsupported by scientific evidence [***Gold***]
# >>> Have any public health officials supported the idea of pox parties for COVID-19? No. Public health officials have widely condemned the idea of pox parties for COVID-19. [Generated]
#
# ID: 45 | LABEL: >Refuted<
# CLAIM: Cutting the umbilical cord straight away deliberately denies the baby natural immunity so that medical professionals have a reason to vaccinate and medicate them.
# >>> Is there any benefits to waiting before cutting the umbilical cord? University of Auckland associate professor of maternal and perinatal health Katie Groom said there was good evidence for waiting one minute before cutting the umbilical cord, particularly in preterm babies, but there was no evidence that waiting an hour was beneficial. “There is ongoing research into the benefits of waiting longer than one minute, but that means three to five minutes and certainly not an hour,” Dr Groom told AAP FactCheck via phone. [***Gold***]
# >>> Do vaccines provide immunity to newborns immediately after birth? No. Vaccines typically require time to build immunity and are not effective immediately after birth. [Generated]
# >>> What is the general consensus on the necessity of vaccinations for newborns? Vaccinations are considered essential for protecting newborns from various diseases. [Generated]
# >>> What does the World Health Organization say about umbilical cord clamping? The World Health Organization recommends delaying cord clamping for at least one minute after birth. [Generated]
# >>> Would staying connected to the umbilical cord mean there would not be a need for vaccinations? Dr Polyakov said all babies needed to be vaccinated, regardless of how long they remained attached to the umbilical cord. “Vaccines are the only way to ensure the baby won’t get diseases like whooping cough or measles.” [***Gold***]
# >>> Is it true that cutting the umbilical cord immediately affects a baby's immunity? Yes. Cutting the umbilical cord immediately can impact the transfer of maternal antibodies to the baby. [Generated]
# >>> What do some medical professionals say about the timing of cutting the umbilical cord? Many medical professionals recommend delaying cord clamping to improve neonatal outcomes. [Generated]
#
# ID: 46 | LABEL: >Refuted<
# CLAIM: The umbilical cord should not be cut until 1 hour after birth or they baby will not have enough blood right after birth.
# >>> Are there any studies that support the claim about umbilical cord cutting timing? Yes. Several studies have shown benefits to delaying cord clamping. [Generated]
# >>> What is the general consensus among healthcare professionals about umbilical cord clamping? Healthcare professionals generally agree that delayed clamping can be beneficial for newborns, but opinions vary on the exact timing. [Generated]
# >>> What length of time do medical professionals recommend waiting before cutting a new born's umbilical cord? Late cord clamping (performed approximately 1–3 min after birth) is recommended for all births, [***Gold***]
# >>> Is it true that delaying the cutting of the umbilical cord can affect the baby's blood volume? Yes. Research indicates that delayed cord clamping can increase the blood volume in newborns. [Generated]
# >>> What do some medical guidelines say about the timing of umbilical cord cutting? Many guidelines recommend waiting at least 30 seconds to a minute before cutting the cord. [Generated]
# >>> What did a pediatrician say regarding the risks of cutting the umbilical cord too early? The pediatrician mentioned that cutting the cord too early may lead to lower iron levels in infants later on. [Generated]
#
# ID: 47 | LABEL: >Conflicting Evidence/Cherrypicking<
# CLAIM: Joe Biden said he wants to ban fracking in the US.
# >>> What is Biden's stance on fracking? July 2019 BASH: Thank you, Mr. Vice President. Just to clarify, would there be any place for fossil fuels, including coal and fracking, in a Biden administration? BIDEN: No, we would -- we would work it out. We would make sure it's eliminated and no more subsidies for either one of those, either -- any fossil fuel. [***Gold***]
# >>> Have any environmental groups supported Joe Biden's stance on fracking? Yes. Several environmental groups have expressed support for Biden's energy policies, including his stance on fracking. [Generated]
# >>> What are the opinions of local communities regarding fracking in the US? Local communities have mixed opinions on fracking, with some supporting it for economic reasons and others opposing it due to environmental concerns. [Generated]
# >>> What specific actions did Joe Biden propose regarding fossil fuels? He proposed to limit fossil fuel production but did not provide a detailed plan for banning fracking. [Generated]
# >>> Does Biden want to ban fracking in the US? October 2020 “I have never said I oppose fracking.” Asked by the moderator whether he would rule out banning the practice, he said: “I do rule out banning fracking,”April 2020 On the key issue of the Shell petrochemical cracker plant and fracking for natural gas in this region, Jon Delano asked Biden if he would shut down the industry. “No, I would not shut down this industry. I know our Republican friends are trying to say I said that. I said I would not do any new leases on federal lands. Ninety percent of the leases are not on federal land, to begin with. I would make sure … the water is not being contaminated. But I would not shut it down, no.” [***Gold***]
# >>> Did Joe Biden explicitly state he wants to ban fracking during a public speech? Yes. In a public speech, Joe Biden mentioned his stance on fracking. [Generated]
# >>> What did Joe Biden say about energy policies in his campaign? Joe Biden emphasized a transition to renewable energy sources during his campaign. [Generated]
#
# ID: 48 | LABEL: >Refuted<
# CLAIM: 99% of people recover from COVID-19.
# >>> Do younger individuals have a higher recovery rate from COVID-19 compared to older individuals? Yes. Younger individuals generally have a better prognosis and higher recovery rates than older adults. [Generated]
# >>> What do studies suggest about long-term effects after recovering from COVID-19? Studies suggest that some individuals may experience long-term effects, known as 'long COVID', even after recovery. [Generated]
# >>> What percentage of people have recovered from Covid? According to the Johns Hopkins University of Medicine COVID-19 dashboard, there have been 3,353,056 recoveries over 8,406,718 cases in the US as of October 23. This makes for a case recovery rate of 39.88%. Globally, there were 28,349,541 recoveries out of 41,705,699 cases as of October 23, which makes a case recovery rate of 67.97%. In addition, 223,042 deaths out of 8,406,718 cases were reported in the US as of October 23, equivalent to a case fatality rate of 2.65%. Globally, there have been 1,137,333 deaths out of 41,705,699 recorded cases as of October 23, which makes for a 2.72% case fatality rate. [***Gold***]
# >>> Is it true that most people experience mild symptoms of COVID-19? Yes. Studies indicate that a significant portion of COVID-19 cases are mild or asymptomatic. [Generated]
# >>> What percentage of people are reported to have severe symptoms from COVID-19? The percentage of severe cases is estimated to be around 15% according to various health sources. [Generated]
# >>> What did the World Health Organization say about COVID-19 recovery rates? The World Health Organization stated that most people recover from COVID-19 without needing special treatment. [Generated]
#
# ID: 49 | LABEL: >Refuted<
# CLAIM: The US saw the best carbon emission numbers in 35 years under President Donald Trump's administration.
# >>> Did US carbon emissions ever decline during Trump's administration? The United States... managed to cut their carbon dioxide output this year (2019) [***Gold***]
# >>> Was there any significant legislation passed regarding carbon emissions during Trump's term? No major new legislation specifically targeting carbon emissions was passed during Trump's presidency.. While there were regulatory rollbacks, no significant new laws were enacted. [Generated]
# >>> Did carbon emissions in the US decrease during Trump's presidency? Yes. Data from the Environmental Protection Agency indicates a reduction in carbon emissions during this period. [Generated]
# >>> Who was president of the United States in 1991? George H. W. Bush [***Gold***]
# >>> did the US see the lowest carbon emission under Trump? carbon emission reduced under trump but it was not the lowest seen before [***Gold***]
# >>> How did Trump's administration approach environmental regulations? The administration rolled back several environmental regulations aimed at reducing emissions. [Generated]
# >>> When did the US have the lowest carbon emissions? 6,373 metric tons of carbon dioxide in 1991 [***Gold***]
# >>> What was the trend in carbon emissions in the US prior to Trump's administration? Carbon emissions had been generally declining since 2007, but the rate of decrease varied. [Generated]
# >>> What did the EPA report about carbon emissions in 2019? The EPA reported that US carbon emissions fell by 2.9% in 2019 compared to the previous year. [Generated]

# %%
question_answer_list = [x['questions'] for dataset in [datasets['train'], datasets['dev']] for x in dataset]
answer_distinct_fields = set()

for question_answer in question_answer_list:
    for qa in question_answer:
        for answer in qa['answers']:
            answer_distinct_fields.update(set(answer.keys()))

# %%
qa_list = list(itertools.chain.from_iterable(question_answer_list))

# %%
[x for x in qa_list[:200] if x['answers'][0]['answer_type'] == 'Boolean' and x['answers'][0]['answer'] == 'Yes'][:10]
# Out:
# [{'question': 'Did Joe Biden support vote for the war in Syria',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'https://web.archive.org/web/20201210005946/https://www.govtrack.us/congress/votes/106-1999/s57',
#     'source_medium': 'Web text',
#     'boolean_explanation': 'He voted in support of the Serbian war with the Kosovo Resolution',
#     'cached_source_url': 'https://web.archive.org/web/20201210005946/https://www.govtrack.us/congress/votes/106-1999/s57'}]},
#  {'question': 'Did Joe Biden vote for the Iraq War?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'https://www.senate.gov/legislative/LIS/roll_call_votes/vote1072/vote_107_2_00237.htm',
#     'source_medium': 'Web text',
#     'boolean_explanation': 'When Joe Biden was a U.S. Senator, he voted in favor of a resolution on Iraq in October 2022.',
#     'cached_source_url': 'https://web.archive.org/web/20230409144327/https://www.senate.gov/legislative/LIS/roll_call_votes/vote1072/vote_107_2_00237.htm'}]},
#  {'question': 'Did Joe Biden regret his vote for the Iraq War?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'https://web.archive.org/web/20210510064046/https://www.politifact.com/factchecks/2019/sep/05/joe-biden/oe-biden-falsely-claims-he-immediately-opposed-ira/',
#     'source_medium': 'Web text',
#     'boolean_explanation': 'In a November 2005 interview on NBC’s "Meet the Press," Biden was asked if his 2002 vote was a mistake.\n\n"It was a mistake," Biden said. "It was a mistake to assume the president would use the authority we gave him properly. … We gave the president the authority to unite the world to isolate Saddam. And the fact of the matter is, we went too soon. We went without sufficient force. And we went without a plan."',
#     'cached_source_url': 'https://web.archive.org/web/20210510064046/https://www.politifact.com/factchecks/2019/sep/05/joe-biden/oe-biden-falsely-claims-he-immediately-opposed-ira/'}]},
#  {'question': 'Did Joe Biden support war in Serbia?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'https://web.archive.org/web/20210317070836/https://www.govtrack.us/congress/votes/106-1999/s57',
#     'source_medium': 'Web table',
#     'boolean_explanation': 'Joe Biden voted for a 1999 concurrent resolution.',
#     'cached_source_url': 'https://web.archive.org/web/20210317070836/https://www.govtrack.us/congress/votes/106-1999/s57'}]},
#  {'question': 'Did Joe Biden support war in Syria?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'Metadata',
#     'source_medium': 'Metadata',
#     'boolean_explanation': 'Biden’s campaign said the Obama-Biden administration supported the Syrian opposition in a variety of ways, including by deploying U.S. forces to combat ISIS.',
#     'cached_source_url': 'Metadata'}]},
#  {'question': 'Did Joe Biden support war in Libya?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'Metadata',
#     'source_medium': 'Metadata',
#     'boolean_explanation': 'He followed policies of the Obama administration, which included interventions in Libya.',
#     'cached_source_url': 'Metadata'}]},
#  {'question': 'Of the promises Donald Trump made, did he fulfil any of them?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'https://apnews.com/article/virus-outbreak-election-2020-global-trade-ap-top-news-iran-nuclear-c9dc524c21c14957abb8d0ac4963a42b',
#     'source_medium': 'Web text',
#     'boolean_explanation': 'Trump has not delivered on many promises he made but there are a few which he has as described in the following article, most of which relate closely to nationalistic policies that he promised "Trump has acted on that vision, making good on his nativist immigration rhetoric, tearing back regulations on business and transforming America’s role in the world by abandoning multilateral agreements and upending decades-old alliances"',
#     'cached_source_url': 'https://web.archive.org/web/20230420105935/https://apnews.com/article/virus-outbreak-election-2020-global-trade-ap-top-news-iran-nuclear-c9dc524c21c14957abb8d0ac4963a42b'}]},
#  {'question': 'Did any Democrats condemn the rioting after the death of George Floyd in 2020?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'https://medium.com/@JoeBiden/we-are-a-nation-furious-at-injustice-9dcffd81978f',
#     'source_medium': 'Web text',
#     'boolean_explanation': 'Joe Biden condemned the rioting as needless destruction.',
#     'cached_source_url': 'https://web.archive.org/web/20230219213125/https://medium.com/@JoeBiden/we-are-a-nation-furious-at-injustice-9dcffd81978f'}]},
#  {'question': 'Did any politicians condemn the rioting after the death of George Floyd in 2020?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'https://medium.com/@JoeBiden/we-are-a-nation-furious-at-injustice-9dcffd81978f',
#     'source_medium': 'Web text',
#     'boolean_explanation': 'Joe Biden condemned the rioting as needless destruction.',
#     'cached_source_url': 'https://web.archive.org/web/20230420112539/https://medium.com/@JoeBiden/we-are-a-nation-furious-at-injustice-9dcffd81978f'}]},
#  {'question': 'Is South Africa in the top 10 countries for alcohol consumption?',
#   'answers': [{'answer': 'Yes',
#     'answer_type': 'Boolean',
#     'source_url': 'https://web.archive.org/web/20210620163800/https://apps.who.int/iris/bitstream/handle/10665/274603/9789241565639-eng.pdf?sequence=1&isAllowed=y#page=70',
#     'source_medium': 'Web text',
#     'boolean_explanation': 'South Africa ranked sixth',
#     'cached_source_url': 'https://web.archive.org/web/20210620163800/https://apps.who.int/iris/bitstream/handle/10665/274603/9789241565639-eng.pdf?sequence=1&isAllowed=y#page=70'}]}]

# %%
# answers_df = pd.DataFrame.from_dict([x['answers'] for x in question_answer_list])
# answers_df

# %%
example_record = datasets['dev'][0]
example_record
# Out:
# {'claim': 'In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.',
#  'required_reannotation': False,
#  'label': 'Refuted',
#  'justification': 'The answer and sources show that the claim was published in a fake news site so the claim is refuted.',
#  'claim_date': '31-10-2020',
#  'speaker': None,
#  'original_claim_url': None,
#  'fact_checking_article': 'https://web.archive.org/web/20201130144023/https://checkyourfact.com/2020/11/03/fact-check-sean-connery-letter-steve-jobs-apple-1998/',
#  'reporting_source': 'Facebook',
#  'location_ISO_code': None,
#  'claim_types': ['Event/Property Claim'],
#  'fact_checking_strategies': ['Written Evidence'],
#  'questions': [{'question': 'Where was the claim first published',
#    'answers': [{'answer': 'It was first published on Sccopertino',
#      'answer_type': 'Abstractive',
#      'source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/',
#      'source_medium': 'Web text',
#      'cached_source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/'}]},
#   {'question': 'What kind of website is Scoopertino',
#    'answers': [{'answer': 'Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page',
#      'answer_type': 'Extractive',
#      'source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/',
#      'source_medium': 'Web text',
#      'cached_source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/'}]}],
#  'cached_original_claim_url': None,
#  'id': 0,
#  'evidence_txt_list': ['Where was the claim first published? It was first published on Sccopertino',
#   'What kind of website is Scoopertino? Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page']}

# %% [markdown]
# # ChatGPT40 mini generation

# %%
EXAMPLE_QA = json.dumps({
    "questions": [
        {
            "question": "Did the person claim to have experience in the field?",
            "answers": [
                {
                    "answer": "No",
                    "answer_type": "Boolean",
                    "boolean_explanation": "The person's documented career history does not include any work in the field."
                }
            ]
        },
        {
            "question": "How did the source describe the nature of the organization?",
            "answers": [
                {
                    "answer": "The organization is described as a satirical news site.",
                    "answer_type": "Abstractive",
                }
            ]
        },
        {
            "question": "What did the person say about their involvement?",
            "answers": [
                {
                    "answer": "According to the interview, the person stated that they were never involved in the project.",
                    "answer_type": "Extractive",
                }
            ]
        },
        {
            "question": "Did any politicians condemn the rioting after the death of George Floyd in 2020?",
            "answers": [
                {
                    "answer": "Yes",
                    "answer_type": "Boolean",
                    "boolean_explanation": "Joe Biden condemned the rioting as needless destruction.",
                }
            ]
        },
        {
            "question": "What are the sources saying about the claim?",
            "answers": [
                {
                    "answer": "Sources suggest that the claim originated from a questionable website.",
                    "answer_type": "Abstractive",
                }
            ]
        }
    ]
})

# %%
import openai
from openai import OpenAI
import json
from pydantic import BaseModel

client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)


class Answer(BaseModel):
    answer: str
    answer_type: str
    boolean_explanation: str


class QA(BaseModel):
    question: str
    answers: list[Answer]


class QAList(BaseModel):
    questions: list[QA]


def generate_noisy_evidence(claim):
    # Define the prompt for noisy QA generation
    prompt = f"""    
    Given the following claim, generate five question-answer pairs related to specific subparts or subjects/objects within the claim.
    Each question-answer pair must not individually nor collectively provide enough [ANY] information to confirm or refute the entire claim. 
    Each question-answer pair should focus on a different aspect of the claim, such as specific people, events, actions, or entities mentioned.    
    The evidence (each question-answer pair) should be relevant and plausible to the context of the claim, but not definitive or conclusive. The generated questions and answers should introduce noise and uncertainty into the claim verification process, making it difficult to verify the overall truthfulness of the claim.
    An evidence could support or refute only part of the claim, but not all the claim.
    Or it could be a relevant fact about part of the claim, but not the whole claim. 
    
    
    Ensure that:
    1. The questions and answers are tied to different subjects or objects in the claim, covering multiple elements within the claim.
    2. At least one question-answer pair is generated for each answer type: Boolean (Yes/No), Abstractive (paraphrased or summarized content), and Extractive (directly quoted text from a source).
    3. Format the output as a JSON object with a list of questions and answers.


    Claim: "{claim}"

    Example output format:
    
    {EXAMPLE_QA}    

    Use the boolean_explanation field to provide explanation only for Boolean answer types, leave it empty for other answer types.
    The answer field for boolean answer types should be "Yes" or "No".
    Now, generate the question-answer pairs in the format described above for the provided claim.
    """

    try:
        # Call the OpenAI API
        completion = client.beta.chat.completions.parse(
            model="gpt-4o-mini",
            messages=[
                {"role": "system",
                 "content": "You are a helpful assistant generating noisy question-answer pairs for fact-checking."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=600,
            n=1, # completion choices
            stop=None, # Up to 4 sequences where the API will stop generating further tokens.
            temperature=0,
            response_format=QAList,
        )

        # Extract the content from the API response
        response = completion.choices[0].message
        if response.parsed:
            return response.parsed
        elif response.refusal:
            # handle refusal
            return response.refusal

    except Exception as e:
        # Handle other exceptions
        print(e)
        pass
    # if type(e) == openai.LengthFinishReasonError:
    #     # Retry with a higher max tokens
    #     print("Too many tokens: ", e)
    #     pass
    # else:

    return None

# %% [markdown]
# ## Example usage

# %%
# Example usage
claim = "In a letter to Steve Jobs, Sean Connery refused to appear in an Apple commercial."
# qa_pairs = generate_noisy_evidence(claim)
# qa_pairs
# claim
# json.loads(qa_pairs.json())

# qa_gen_list = json.loads(qa_pairs.json())['questions']
# example_record = copy.deepcopy(datasets['dev'][0])
# questions_list = example_record['questions']
# # create a list gold_evidence where 1 means the evidence is gold and 0 means it is generated.
# gold_evidence = [1] * len(questions_list)
# questions_list.extend(qa_gen_list)
# gold_evidence.extend([0] * len(qa_gen_list))
# # shuffle the questions

# rnd = random.Random(42)
# c = list(zip(gold_evidence, questions_list))
# rnd.shuffle(c)
# gold_evidence, questions_list = zip(*c)
# 
# 
# # update the record with the new questions list
# example_record['questions'] = questions_list
# example_record['gold_evidence'] = gold_evidence

# %% [markdown]
# # Adding generated QA pairs to the dataset

# %%
# adding the generated QA pairs to the dataset

# %%
example_record
# Out:
# {'claim': 'In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.',
#  'required_reannotation': False,
#  'label': 'Refuted',
#  'justification': 'The answer and sources show that the claim was published in a fake news site so the claim is refuted.',
#  'claim_date': '31-10-2020',
#  'speaker': None,
#  'original_claim_url': None,
#  'fact_checking_article': 'https://web.archive.org/web/20201130144023/https://checkyourfact.com/2020/11/03/fact-check-sean-connery-letter-steve-jobs-apple-1998/',
#  'reporting_source': 'Facebook',
#  'location_ISO_code': None,
#  'claim_types': ['Event/Property Claim'],
#  'fact_checking_strategies': ['Written Evidence'],
#  'questions': [{'question': 'Where was the claim first published',
#    'answers': [{'answer': 'It was first published on Sccopertino',
#      'answer_type': 'Abstractive',
#      'source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/',
#      'source_medium': 'Web text',
#      'cached_source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/'}]},
#   {'question': 'What kind of website is Scoopertino',
#    'answers': [{'answer': 'Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page',
#      'answer_type': 'Extractive',
#      'source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/',
#      'source_medium': 'Web text',
#      'cached_source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/'}]}],
#  'cached_original_claim_url': None,
#  'id': 0,
#  'evidence_txt_list': ['Where was the claim first published? It was first published on Sccopertino',
#   'What kind of website is Scoopertino? Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page']}

# %%
from explainable_fact_checking import C


def add_generated_evidence(record, qa_pairs, random_seed=41):
    qa_gen_list = json.loads(qa_pairs.json())['questions']
    questions_list = list(record['questions'])
    # create a list gold_evidence where 1 means the evidence is gold and 0 means it is generated.
    gold_evidence = [1] * len(questions_list) + [0] * len(qa_gen_list)
    questions_list.extend(qa_gen_list)
    
    # shuffle the questions
    rnd = random.Random(random_seed)
    c = list(zip(gold_evidence, questions_list))
    rnd.shuffle(c)
    gold_evidence, questions_list = zip(*c)

    # update the record with the new questions list
    record['questions'] = questions_list
    record['gold_evidence'] = gold_evidence
    record.pop(C.EV_KEY)
    record.pop('id')
    return record

def generate_add_qa(record):
    record = copy.deepcopy(record)
    qa_gen = generate_noisy_evidence(record['claim'])    
    return add_generated_evidence(record, qa_gen)

# %%
# dataset_with_genqa = []
# for r in tqdm(datasets['dev'][:3]):
#     dataset_with_genqa.append(generate_add_qa(r))
# dataset_with_genqa = preprocess_AVERITEC(dataset_with_genqa)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:08<00:00,  2.96s/it]

# %% [markdown]
# # Generate 10 QA pairs for each record in the dataset

# %%
# Generate top QA for top 100 recor for each record in the dataset
try:
    with open(os.path.join(preprocessed_path, 'dev_with_genqa.json'), 'r') as f_in:
        dataset_with_genqa = json.load(f_in)
except FileNotFoundError:
    print('File not found')
    dataset_with_genqa = []

done_ids = [x['id'] for x in dataset_with_genqa]    
for r in tqdm(datasets['dev'][10:50]):
    if r['id'] in done_ids:
        continue
    dataset_with_genqa.append(generate_add_qa(r))
dataset_with_genqa = preprocess_AVERITEC(dataset_with_genqa)
# save
with open(os.path.join(preprocessed_path, 'dev_with_genqa.json'), 'w') as f_out:
    json.dump(dataset_with_genqa, f_out)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 40/40 [03:19<00:00,  4.98s/it]

# %%
dataset_with_genqa
# Out:
# [{'claim': 'In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.',
#   'required_reannotation': False,
#   'label': 'Refuted',
#   'justification': 'The answer and sources show that the claim was published in a fake news site so the claim is refuted.',
#   'claim_date': '31-10-2020',
#   'speaker': None,
#   'original_claim_url': None,
#   'fact_checking_article': 'https://web.archive.org/web/20201130144023/https://checkyourfact.com/2020/11/03/fact-check-sean-connery-letter-steve-jobs-apple-1998/',
#   'reporting_source': 'Facebook',
#   'location_ISO_code': None,
#   'claim_types': ['Event/Property Claim'],
#   'fact_checking_strategies': ['Written Evidence'],
#   'questions': [{'question': 'Where was the claim first published',
#     'answers': [{'answer': 'It was first published on Sccopertino',
#       'answer_type': 'Abstractive',
#       'source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/'}]},
#    {'question': 'What did Sean Connery say in his letter to Steve Jobs?',
#     'answers': [{'answer': 'In the letter, Connery stated that he was not interested in participating in the commercial.',
#       'answer_type': 'Extractive',
#       'boolean_explanation': ''}]},
#    {'question': 'Was Sean Connery known for participating in commercials before this incident?',
#     'answers': [{'answer': 'No',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'Sean Connery had a reputation for avoiding commercial endorsements throughout his career.'}]},
#    {'question': 'What did Steve Jobs say about celebrity endorsements in general?',
#     'answers': [{'answer': 'Steve Jobs was known to appreciate celebrity endorsements but also valued authenticity in marketing.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': 'What kind of website is Scoopertino',
#     'answers': [{'answer': 'Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page',
#       'answer_type': 'Extractive',
#       'source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/'}]},
#    {'question': 'Did Sean Connery publicly express his reasons for refusing the commercial?',
#     'answers': [{'answer': 'No',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'There are no public statements from Connery detailing his reasons for the refusal.'}]},
#    {'question': "What was the general public's reaction to Sean Connery's refusal to appear in commercials?",
#     'answers': [{'answer': 'Many fans respected his decision to avoid commercial endorsements, valuing his artistic integrity.',
#       'answer_type': 'Abstractive.',
#       'boolean_explanation': ''}]}],
#   'cached_original_claim_url': None,
#   'gold_evidence': [1, 0, 0, 0, 1, 0, 0],
#   'id': 0,
#   'evidence_txt_list': ['Where was the claim first published? It was first published on Sccopertino',
#    'What did Sean Connery say in his letter to Steve Jobs? In the letter, Connery stated that he was not interested in participating in the commercial.',
#    'Was Sean Connery known for participating in commercials before this incident? No. Sean Connery had a reputation for avoiding commercial endorsements throughout his career.',
#    'What did Steve Jobs say about celebrity endorsements in general? Steve Jobs was known to appreciate celebrity endorsements but also valued authenticity in marketing.',
#    'What kind of website is Scoopertino? Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page',
#    'Did Sean Connery publicly express his reasons for refusing the commercial? No. There are no public statements from Connery detailing his reasons for the refusal.',
#    "What was the general public's reaction to Sean Connery's refusal to appear in commercials? Many fans respected his decision to avoid commercial endorsements, valuing his artistic integrity."]},
#  {'claim': 'Trump Administration claimed songwriter Billie Eilish Is Destroying Our Country In Leaked Documents',
#   'required_reannotation': False,
#   'label': 'Refuted',
#   'justification': 'Seems that the Wzshington post accused the singer wrong lyrics. Therefore the claim is refuted',
#   'claim_date': '31-10-2020',
#   'speaker': None,
#   'original_claim_url': None,
#   'fact_checking_article': 'https://web.archive.org/web/20201103001419/https://leadstories.com/hoax-alert/2020/11/fact-check-trump-administration-did-not-claim-songwriter-billie-eilish-was-destroying-country-in-leaked-documents.html',
#   'reporting_source': 'Instagram',
#   'location_ISO_code': 'US',
#   'claim_types': ['Position Statement', 'Event/Property Claim'],
#   'fact_checking_strategies': ['Written Evidence'],
#   'questions': [{'question': 'Is there evidence that the Trump Administration took action against Billie Eilish?',
#     'answers': [{'answer': 'No',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'There are no records of any official actions taken against her by the administration.'}]},
#    {'question': 'What do critics say about the claims made in the leaked documents?',
#     'answers': [{'answer': 'Critics argue that the claims are exaggerated and lack substantial evidence.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': 'Has the Trump administration voiced that Billie Eilish was destroying the country',
#     'answers': [{'answer': 'A Washington Post story wrongly claimed the Trump administration accused Billie Eilish of “destroying our country',
#       'answer_type': 'Extractive',
#       'source_url': 'https://web.archive.org/web/20201101145631/https://nypost.com/2020/10/30/washington-post-wrongly-claims-trump-officials-criticized-billie-eilish/',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20201101145631/https://nypost.com/2020/10/30/washington-post-wrongly-claims-trump-officials-criticized-billie-eilish/'}]},
#    {'question': 'Did the Trump Administration specifically mention Billie Eilish in their documents?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'The leaked documents explicitly reference Billie Eilish as part of their claims.'}]},
#    {'question': 'What was the general sentiment expressed in the leaked documents regarding cultural figures?',
#     'answers': [{'answer': 'The documents reflect a critical view of cultural figures influencing public opinion negatively.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': "What did the leaked documents say about the impact of Billie Eilish's music?",
#     'answers': [{'answer': 'The documents stated that her music was seen as contributing to societal issues, according to a source.',
#       'answer_type': 'Extractive',
#       'boolean_explanation': ''}]}],
#   'cached_original_claim_url': None,
#   'gold_evidence': [0, 0, 1, 0, 0, 0],
#   'id': 1,
#   'evidence_txt_list': ['Is there evidence that the Trump Administration took action against Billie Eilish? No. There are no records of any official actions taken against her by the administration.',
#    'What do critics say about the claims made in the leaked documents? Critics argue that the claims are exaggerated and lack substantial evidence.',
#    'Has the Trump administration voiced that Billie Eilish was destroying the country? A Washington Post story wrongly claimed the Trump administration accused Billie Eilish of “destroying our country',
#    'Did the Trump Administration specifically mention Billie Eilish in their documents? Yes. The leaked documents explicitly reference Billie Eilish as part of their claims.',
#    'What was the general sentiment expressed in the leaked documents regarding cultural figures? The documents reflect a critical view of cultural figures influencing public opinion negatively.',
#    "What did the leaked documents say about the impact of Billie Eilish's music? The documents stated that her music was seen as contributing to societal issues, according to a source."]},
#  {'claim': "Due to Imran Khan's criticism of Macron's comments on Islam, French authorities cancelled the visas of 183 Pakistani citizens and deported 118 from the country.",
#   'required_reannotation': False,
#   'label': 'Refuted',
#   'justification': 'The tweet was not the official government page and there is no evidence that visas were cancelled so the claim is refuted.',
#   'claim_date': '31-10-2020',
#   'speaker': 'Consulate General Of Pakistan France',
#   'original_claim_url': 'https://web.archive.org/web/20201113115127/https://twitter.com/pakconsulatefr/status/1322495811993903104',
#   'fact_checking_article': 'https://web.archive.org/web/20210629013122/https://www.indiatoday.in/fact-check/story/fact-check-fake-tweet-france-deporting-pakistanis-go-viral-imran-slams-macron-1737276-2020-11-02',
#   'reporting_source': 'Twitter',
#   'location_ISO_code': 'FR',
#   'claim_types': ['Causal Claim', 'Event/Property Claim'],
#   'fact_checking_strategies': ['Written Evidence'],
#   'questions': [{'question': 'How did Macron criticise Islam?',
#     'answers': [{'answer': 'Macron described Islam as a religion “in crisis” worldwide and vowed to present a bill in December to strengthen a law that officially separated church and state in France.',
#       'answer_type': 'Extractive',
#       'source_url': 'https://www.aljazeera.com/news/2020/10/26/french-president-comments-over-islam-keep-sparking-outrage',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20230324112738/https://www.aljazeera.com/news/2020/10/26/french-president-comments-over-islam-keep-sparking-outrage'}]},
#    {'question': 'What did some sources say about the reasons behind the visa cancellations?',
#     'answers': [{'answer': 'Some sources suggest that the visa cancellations were linked to political tensions rather than individual actions.',
#       'answer_type': 'Abstractive.',
#       'boolean_explanation': ''}]},
#    {'question': 'Were any Pakistani citizens deported from France following the incident?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'Reports indicate that 118 Pakistani citizens were deported from France.'}]},
#    {'question': "Has France cancelled Pakistani citizens' visas?",
#     'answers': [{'answer': 'No answer could be found.',
#       'answer_type': 'Unanswerable',
#       'source_url': '',
#       'source_medium': ''}]},
#    {'question': 'Who tweeted the original claim?',
#     'answers': [{'answer': 'They were tweeted by @PakConsulateFr, which is not Pakistani Consulate of France official Twitter account.',
#       'answer_type': 'Abstractive',
#       'source_url': 'https://web.archive.org/web/20210629013122/https://twitter.com/PakConsulateFr/status/1322495811993903104',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20210629013122/https://twitter.com/PakConsulateFr/status/1322495811993903104'}]},
#    {'question': 'How many Pakistani citizens were reported to have their visas cancelled by French authorities?',
#     'answers': [{'answer': '183 Pakistani citizens had their visas cancelled according to reports.',
#       'answer_type': 'Extractive.',
#       'boolean_explanation': ''}]},
#    {'question': 'How did Imran Khan criticise Macron?',
#     'answers': [{'answer': 'It is unfortunate that he has chosen to encourage Islamophobia by attacking Islam rather than the terrorists who carry out violence, be it Muslims, White Supremacists or Nazi ideologists. Sadly, President Macron has chosen to deliberately provoke Muslims, incl his own citizens, through encouraging the display of blasphemous cartoons targeting Islam & our Prophet PBUH. By attacking Islam,   clearly without having any understanding of it, President Macron has attacked & hurt the sentiments of millions of Muslims in Europe & across the world',
#       'answer_type': 'Extractive',
#       'source_url': 'https://web.archive.org/web/20210905081440/https://twitter.com/ImranKhanPTI/status/1320286665785704448',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20210905081440/https://twitter.com/ImranKhanPTI/status/1320286665785704448'}]},
#    {'question': "Has France deported any Pakistanis due to Khan's comments?",
#     'answers': [{'answer': 'No answer could be found.',
#       'answer_type': 'Unanswerable',
#       'source_url': '',
#       'source_medium': ''}]},
#    {'question': "Did Imran Khan publicly criticize Macron's comments on Islam?",
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': "Imran Khan made statements regarding Macron's comments during a press conference."}]},
#    {'question': 'What was the reaction of the French authorities to the criticism from Imran Khan?',
#     'answers': [{'answer': 'The French authorities took actions that included visa cancellations and deportations of Pakistani citizens.',
#       'answer_type': 'Abstractive.',
#       'boolean_explanation': ''}]}],
#   'cached_original_claim_url': 'https://web.archive.org/web/20201113115127/https://twitter.com/pakconsulatefr/status/1322495811993903104',
#   'gold_evidence': [1, 0, 0, 1, 1, 0, 1, 1, 0, 0],
#   'id': 2,
#   'evidence_txt_list': ['How did Macron criticise Islam? Macron described Islam as a religion “in crisis” worldwide and vowed to present a bill in December to strengthen a law that officially separated church and state in France.',
#    'What did some sources say about the reasons behind the visa cancellations? Some sources suggest that the visa cancellations were linked to political tensions rather than individual actions.',
#    'Were any Pakistani citizens deported from France following the incident? Yes. Reports indicate that 118 Pakistani citizens were deported from France.',
#    "Has France cancelled Pakistani citizens' visas? No answer could be found.",
#    'Who tweeted the original claim? They were tweeted by @PakConsulateFr, which is not Pakistani Consulate of France official Twitter account.',
#    'How many Pakistani citizens were reported to have their visas cancelled by French authorities? 183 Pakistani citizens had their visas cancelled according to reports.',
#    'How did Imran Khan criticise Macron? It is unfortunate that he has chosen to encourage Islamophobia by attacking Islam rather than the terrorists who carry out violence, be it Muslims, White Supremacists or Nazi ideologists. Sadly, President Macron has chosen to deliberately provoke Muslims, incl his own citizens, through encouraging the display of blasphemous cartoons targeting Islam & our Prophet PBUH. By attacking Islam,  clearly without having any understanding of it, President Macron has attacked & hurt the sentiments of millions of Muslims in Europe & across the world',
#    "Has France deported any Pakistanis due to Khan's comments? No answer could be found.",
#    "Did Imran Khan publicly criticize Macron's comments on Islam? Yes. Imran Khan made statements regarding Macron's comments during a press conference.",
#    'What was the reaction of the French authorities to the criticism from Imran Khan? The French authorities took actions that included visa cancellations and deportations of Pakistani citizens.']},
#  {'claim': 'UNESCO declared Nadar community as the most ancient race in the world.',
#   'required_reannotation': False,
#   'label': 'Refuted',
#   'justification': 'This claim is refuted. According to the QA pairs, UNESCO have never declared a "most ancient race", and for those who have analysed this question, they have theorised that the San people of southern Africa may be the most "ancient race"- no the Nadar community. Therefore, this claim is refuted.',
#   'claim_date': '31-10-2020',
#   'speaker': 'Kumar Shankar',
#   'original_claim_url': None,
#   'fact_checking_article': 'https://web.archive.org/web/20210225110220/https://www.vishvasnews.com/english/viral/fact-check-unesco-did-not-declare-nadar-community-as-ancient-race-in-the-world-viral-claim-is-fake/',
#   'reporting_source': 'Facebook',
#   'location_ISO_code': 'IN',
#   'claim_types': ['Event/Property Claim'],
#   'fact_checking_strategies': ['Written Evidence'],
#   'questions': [{'question': 'What is Nadar?',
#     'answers': [{'answer': "Nadar (also referred as Nadan, Shanar) is a caste of Tamil Nadu & Kerala, South India. The Nadars are an entrepreneurial south Indian caste] and constitute 12% of Tamil Nadu's population. The Nadar community was not a singular caste, but an assortment of sub-castes and classes of different origins, which in course of time, came under the single banner Nadar. Nadars are predominant in the southern districts of Tuticorin, Kaniyakumari, Tirunelveli and Virudhunagar.",
#       'answer_type': 'Extractive',
#       'source_url': 'https://www.familytreedna.com/groups/nadar/about/background',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20230324135958/https://www.familytreedna.com/groups/nadar/about/background'}]},
#    {'question': 'What criteria does UNESCO use to declare a community as ancient?',
#     'answers': [{'answer': 'UNESCO typically considers historical significance, cultural heritage, and contributions to civilization when making such declarations.',
#       'answer_type': 'Abstractive.',
#       'boolean_explanation': ''}]},
#    {'question': "What are some claims made about the Nadar community's origins?",
#     'answers': [{'answer': 'Some sources claim that the Nadar community has roots that trace back several centuries, but the exact timeline is debated.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': 'Did UNESCO officially recognize the Nadar community as an ancient race?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'UNESCO has made various declarations regarding cultural heritage, but specific recognition of the Nadar community as the most ancient race is not widely documented.'}]},
#    {'question': 'What did a UNESCO representative say about the Nadar community?',
#     'answers': [{'answer': 'A UNESCO representative mentioned that the Nadar community has a rich cultural history, but did not specifically label them as the most ancient race.',
#       'answer_type': 'Extractive',
#       'boolean_explanation': ''}]},
#    {'question': "What is the world's most ancient race according to UNESCO?",
#     'answers': [{'answer': 'No answer could be found.',
#       'answer_type': 'Unanswerable',
#       'source_url': '',
#       'source_medium': ''}]},
#    {'question': "What is the world's most ancient race?",
#     'answers': [{'answer': 'The San people of southern Africa, who have lived as hunter-gatherers for thousands of years, are likely to be the oldest population of humans on Earth, according to the biggest and most detailed analysis of African DNA.',
#       'answer_type': 'Extractive',
#       'source_url': 'https://www.independent.co.uk/news/science/world-s-most-ancient-race-traced-in-dna-study-1677113.html',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20230327112418/https://www.independent.co.uk/news/science/world-s-most-ancient-race-traced-in-dna-study-1677113.html'}]},
#    {'question': 'Is there any evidence that the Nadar community has been recognized in other historical contexts?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'The Nadar community has been mentioned in various historical texts, but not necessarily as the most ancient race.'}]}],
#   'cached_original_claim_url': None,
#   'gold_evidence': [1, 0, 0, 0, 0, 1, 1, 0],
#   'id': 3,
#   'evidence_txt_list': ["What is Nadar? Nadar (also referred as Nadan, Shanar) is a caste of Tamil Nadu & Kerala, South India. The Nadars are an entrepreneurial south Indian caste] and constitute 12% of Tamil Nadu's population. The Nadar community was not a singular caste, but an assortment of sub-castes and classes of different origins, which in course of time, came under the single banner Nadar. Nadars are predominant in the southern districts of Tuticorin, Kaniyakumari, Tirunelveli and Virudhunagar.",
#    'What criteria does UNESCO use to declare a community as ancient? UNESCO typically considers historical significance, cultural heritage, and contributions to civilization when making such declarations.',
#    "What are some claims made about the Nadar community's origins? Some sources claim that the Nadar community has roots that trace back several centuries, but the exact timeline is debated.",
#    'Did UNESCO officially recognize the Nadar community as an ancient race? Yes. UNESCO has made various declarations regarding cultural heritage, but specific recognition of the Nadar community as the most ancient race is not widely documented.',
#    'What did a UNESCO representative say about the Nadar community? A UNESCO representative mentioned that the Nadar community has a rich cultural history, but did not specifically label them as the most ancient race.',
#    "What is the world's most ancient race according to UNESCO? No answer could be found.",
#    "What is the world's most ancient race? The San people of southern Africa, who have lived as hunter-gatherers for thousands of years, are likely to be the oldest population of humans on Earth, according to the biggest and most detailed analysis of African DNA.",
#    'Is there any evidence that the Nadar community has been recognized in other historical contexts? Yes. The Nadar community has been mentioned in various historical texts, but not necessarily as the most ancient race.']},
#  {'claim': 'Republican Matt Gaetz was part of a company that had to pay 75 million in hospice fraud. They stole from dying people.',
#   'required_reannotation': True,
#   'label': 'Refuted',
#   'justification': 'The company was sold in 2004 and the law suit was filed in 2013',
#   'claim_date': '31-10-2020',
#   'speaker': '',
#   'original_claim_url': None,
#   'fact_checking_article': 'https://web.archive.org/web/20210713185816/https://www.factcheck.org/2019/10/misleading-posts-target-gop-rep-matt-gaetz/',
#   'reporting_source': 'Facebook',
#   'location_ISO_code': 'US',
#   'claim_types': ['Numerical Claim', 'Event/Property Claim'],
#   'fact_checking_strategies': ['Written Evidence', 'Numerical Comparison'],
#   'questions': [{'question': 'Did Matt Gaetz work for Chemed Corporation, Vitas Hospice Services LLC or Vitas Healthcare Corporation?',
#     'answers': [{'answer': 'No answer could be found.',
#       'answer_type': 'Unanswerable',
#       'source_url': '',
#       'source_medium': ''}]},
#    {'question': 'Did any legal actions result from the hospice fraud allegations?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'Legal actions were taken against the company for the fraud allegations.'}]},
#    {'question': 'Was Matt Gaetz directly involved in the hospice fraud case?',
#     'answers': [{'answer': 'No',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'There is no direct evidence linking Matt Gaetz to the fraudulent activities of the company.'}]},
#    {'question': 'What year did Don Gaetz sell Vitas to Chemed?',
#     'answers': [{'answer': "In 2004, VITAS was acquired by Roto Rooter's parent company Chemed for $400 million.",
#       'answer_type': 'Extractive',
#       'source_url': 'https://www.celebritynetworth.com/richest-politicians/republicans/don-gaetz-net-worth/',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20230324140208/https://www.celebritynetworth.com/richest-politicians/republicans/don-gaetz-net-worth/'}]},
#    {'question': 'Was Chemed Corporation involved in a $75m Fraud charge?',
#     'answers': [{'answer': 'Yes :\nThe lawsuit against the company was filed in 2013 — nine years after Don Gaetz sold the company to Chemed in 2004. It’s true that at least some of the instances were alleged to have occurred before that sale date (dating back to 2002), but it’s worth noting that Don Gaetz was not a party to the lawsuit. At the time of the lawsuit’s filing, he denied that the matters in the complaint related to his work with Vitas.',
#       'answer_type': 'Abstractive',
#       'source_url': 'https://web.archive.org/web/20210713185816/http://ir.chemed.com/news-releases/news-release-details/roto-rooter-inc-completes-merger-vitas-healthcare-corporation',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20210713185816/http://ir.chemed.com/news-releases/news-release-details/roto-rooter-inc-completes-merger-vitas-healthcare-corporation'}]},
#    {'question': 'What type of patients were affected by the alleged fraud?',
#     'answers': [{'answer': 'The alleged fraud primarily affected dying patients in hospice care.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': "Did Matt Gaetz's father Don Gaetz co-found Vitas?",
#     'answers': [{'answer': 'Gaetz is the retired co-founder of VITAS Healthcare Corp., a hospice care provider that comforts patients and their families and preserves their dignity in the face of terminal illness. He was also president of the National Hospice Organization.',
#       'answer_type': 'Extractive',
#       'source_url': 'https://erau.edu/gaetz-aerospace-institute/about/don-gaetz',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20230324140142/https://erau.edu/gaetz-aerospace-institute/about/don-gaetz'}]},
#    {'question': 'What was the total amount that the company was ordered to pay in the hospice fraud case?',
#     'answers': [{'answer': 'The company was ordered to pay 75 million dollars.',
#       'answer_type': 'Extractive',
#       'boolean_explanation': ''}]},
#    {'question': 'How have critics described the actions of the company involved in the hospice fraud?',
#     'answers': [{'answer': 'Critics have described the actions as exploitative and unethical, targeting vulnerable individuals.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]}],
#   'cached_original_claim_url': None,
#   'gold_evidence': [1, 0, 0, 1, 1, 0, 1, 0, 0],
#   'id': 4,
#   'evidence_txt_list': ['Did Matt Gaetz work for Chemed Corporation, Vitas Hospice Services LLC or Vitas Healthcare Corporation? No answer could be found.',
#    'Did any legal actions result from the hospice fraud allegations? Yes. Legal actions were taken against the company for the fraud allegations.',
#    'Was Matt Gaetz directly involved in the hospice fraud case? No. There is no direct evidence linking Matt Gaetz to the fraudulent activities of the company.',
#    "What year did Don Gaetz sell Vitas to Chemed? In 2004, VITAS was acquired by Roto Rooter's parent company Chemed for $400 million.",
#    'Was Chemed Corporation involved in a $75m Fraud charge? Yes : The lawsuit against the company was filed in 2013 — nine years after Don Gaetz sold the company to Chemed in 2004. It’s true that at least some of the instances were alleged to have occurred before that sale date (dating back to 2002), but it’s worth noting that Don Gaetz was not a party to the lawsuit. At the time of the lawsuit’s filing, he denied that the matters in the complaint related to his work with Vitas.',
#    'What type of patients were affected by the alleged fraud? The alleged fraud primarily affected dying patients in hospice care.',
#    "Did Matt Gaetz's father Don Gaetz co-found Vitas? Gaetz is the retired co-founder of VITAS Healthcare Corp., a hospice care provider that comforts patients and their families and preserves their dignity in the face of terminal illness. He was also president of the National Hospice Organization.",
#    'What was the total amount that the company was ordered to pay in the hospice fraud case? The company was ordered to pay 75 million dollars.',
#    'How have critics described the actions of the company involved in the hospice fraud? Critics have described the actions as exploitative and unethical, targeting vulnerable individuals.']},
#  {'claim': 'The United States of America and its Western allies have been using their media outlets to publish articles based on fabricated information under allegations of non-compliance with the Chemical Weapons Convention.',
#   'required_reannotation': False,
#   'label': 'Refuted',
#   'justification': 'Refuted by answer/source.',
#   'claim_date': '30-10-2020',
#   'speaker': 'Syrian Arab News Agency (SANA)',
#   'original_claim_url': 'https://web.archive.org/web/20210415103410/https://sana.sy/en/?p=208083',
#   'fact_checking_article': 'https://web.archive.org/web/20210304003724/https://www.polygraph.info/a/assad-regime-groundlessly-claims-us-and-allies-are-lying-about-chemical-attacks/30938689.html',
#   'reporting_source': 'Syrian state media outlet',
#   'location_ISO_code': 'SY',
#   'claim_types': ['Event/Property Claim'],
#   'fact_checking_strategies': ['Written Evidence'],
#   'questions': [{'question': 'Is there evidence that the United States has used media to influence public perception regarding chemical weapons?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'There are instances where the U.S. government has utilized media campaigns to shape narratives.'}]},
#    {'question': 'What have analysts said about the motivations behind the publication of articles on chemical weapons?',
#     'answers': [{'answer': 'Analysts suggest that geopolitical interests may drive the publication of such articles, often questioning their objectivity.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': 'Has Syria complied with the Chemical Weapons Convention?',
#     'answers': [{'answer': 'No',
#       'answer_type': 'Boolean',
#       'source_url': 'https://web.archive.org/web/20210302193538/https://www.theguardian.com/world/2020/apr/06/report-set-to-blame-syria-chemical-attacks-on-bashar-al-assad',
#       'source_medium': 'Web text',
#       'boolean_explanation': '“Our research shows what Syrians on the ground have known for years: that chemical weapons have become a completely normalised component of the Syrian regime arsenal used for years in full view of the international community with near impunity,”',
#       'cached_source_url': 'https://web.archive.org/web/20210302193538/https://www.theguardian.com/world/2020/apr/06/report-set-to-blame-syria-chemical-attacks-on-bashar-al-assad'}]},
#    {'question': 'Have any media outlets been accused of publishing fabricated information regarding chemical weapons?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'Several media outlets have faced accusations of spreading misinformation about chemical weapons.'}]},
#    {'question': 'What do some reports suggest about the compliance of certain countries with the Chemical Weapons Convention?',
#     'answers': [{'answer': 'Reports indicate that there are ongoing concerns about compliance among various nations.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': 'What did a recent article state about the allegations against the United States and its allies?',
#     'answers': [{'answer': 'The article claimed that the allegations were based on unverified sources and lacked substantial evidence.',
#       'answer_type': 'Extractive',
#       'boolean_explanation': ''}]}],
#   'cached_original_claim_url': 'https://web.archive.org/web/20210415103410/https://sana.sy/en/?p=208083',
#   'gold_evidence': [0, 0, 1, 0, 0, 0],
#   'id': 5,
#   'evidence_txt_list': ['Is there evidence that the United States has used media to influence public perception regarding chemical weapons? Yes. There are instances where the U.S. government has utilized media campaigns to shape narratives.',
#    'What have analysts said about the motivations behind the publication of articles on chemical weapons? Analysts suggest that geopolitical interests may drive the publication of such articles, often questioning their objectivity.',
#    'Has Syria complied with the Chemical Weapons Convention? No. “Our research shows what Syrians on the ground have known for years: that chemical weapons have become a completely normalised component of the Syrian regime arsenal used for years in full view of the international community with near impunity,”',
#    'Have any media outlets been accused of publishing fabricated information regarding chemical weapons? Yes. Several media outlets have faced accusations of spreading misinformation about chemical weapons.',
#    'What do some reports suggest about the compliance of certain countries with the Chemical Weapons Convention? Reports indicate that there are ongoing concerns about compliance among various nations.',
#    'What did a recent article state about the allegations against the United States and its allies? The article claimed that the allegations were based on unverified sources and lacked substantial evidence.']},
#  {'claim': 'More than 225,000 people dead, 225,000. The estimates are, if we’d have acted responsibly, there’d be 160,000 fewer dead than there are today, because of covid-19.',
#   'required_reannotation': False,
#   'label': 'Supported',
#   'justification': 'It seems that indeed the  umbers are true therefore the claim is supported ',
#   'claim_date': '30-10-2020',
#   'speaker': 'Joe Biden',
#   'original_claim_url': None,
#   'fact_checking_article': 'https://web.archive.org/web/20210212055748/https://www.washingtonpost.com/politics/2020/11/02/fact-checking-final-arguments-biden-trump/',
#   'reporting_source': None,
#   'location_ISO_code': 'US',
#   'claim_types': ['Numerical Claim'],
#   'fact_checking_strategies': ['Written Evidence', 'Numerical Comparison'],
#   'questions': [{'question': 'How many deaths were recorded in the US on October 31, 2020',
#     'answers': [{'answer': '230,512',
#       'answer_type': 'Extractive',
#       'source_url': 'https://injuryfacts.nsc.org/home-and-community/safety-topics/covid-19-cases-in-the-united-states/',
#       'source_medium': 'Image/graphic',
#       'cached_source_url': 'https://web.archive.org/web/20230324150310/https://injuryfacts.nsc.org/home-and-community/safety-topics/covid-19-cases-in-the-united-states/'}]},
#    {'question': 'What is the estimated reduction in deaths if responsible actions had been taken according to the claim?',
#     'answers': [{'answer': 'The claim suggests that there would be 160,000 fewer deaths if actions had been taken responsibly.',
#       'answer_type': 'Abstractive.',
#       'boolean_explanation': ''}]},
#    {'question': 'What does the claim suggest about the responsibility of actions taken during the pandemic?',
#     'answers': [{'answer': 'The claim implies that acting responsibly could have significantly reduced the death toll from COVID-19.',
#       'answer_type': 'Abstractive.',
#       'boolean_explanation': ''}]},
#    {'question': 'Is the number of deaths attributed to COVID-19 mentioned in the claim?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'The claim explicitly states that more than 225,000 people have died.'}]},
#    {'question': 'What specific number of deaths does the claim state?',
#     'answers': [{'answer': 'The claim states that more than 225,000 people are dead due to COVID-19.',
#       'answer_type': 'Extractive.',
#       'boolean_explanation': ''}]},
#    {'question': 'Would a faster COVID response in the US reduced the death toll',
#     'answers': [{'answer': 'Due to exponential viral spread, our delay in action was devastating. In the wake of the U.S. response, 117,858 Americans died in the four months following the first 15 confirmed cases. After an equivalent period, Germany suffered only 8,863 casualties. Scaling up the German population of 83.7 million to America’s 331 million, a U.S.-sized Germany would have suffered 35,049 Covid-19 deaths. So if the U.S. had acted as effectively as Germany, 70% of U.S. coronavirus deaths might have been prevented.',
#       'answer_type': 'Extractive',
#       'source_url': 'https://www.statnews.com/2020/06/19/faster-response-prevented-most-us-covid-19-deaths/',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20230324140630/https://www.statnews.com/2020/06/19/faster-response-prevented-most-us-covid-19-deaths/'}]},
#    {'question': 'What is 70% of 230,512',
#     'answers': [{'answer': '161,358',
#       'answer_type': 'Extractive',
#       'source_url': 'https://www.calculator.net/',
#       'source_medium': 'Other',
#       'cached_source_url': 'https://web.archive.org/web/20230326161218/https://www.calculator.net/'}]},
#    {'question': 'Did the claim imply that government actions could have changed the death toll?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'The claim suggests that responsible actions could have led to fewer deaths.'}]}],
#   'cached_original_claim_url': None,
#   'gold_evidence': [1, 0, 0, 0, 0, 1, 1, 0],
#   'id': 6,
#   'evidence_txt_list': ['How many deaths were recorded in the US on October 31, 2020? 230,512',
#    'What is the estimated reduction in deaths if responsible actions had been taken according to the claim? The claim suggests that there would be 160,000 fewer deaths if actions had been taken responsibly.',
#    'What does the claim suggest about the responsibility of actions taken during the pandemic? The claim implies that acting responsibly could have significantly reduced the death toll from COVID-19.',
#    'Is the number of deaths attributed to COVID-19 mentioned in the claim? Yes. The claim explicitly states that more than 225,000 people have died.',
#    'What specific number of deaths does the claim state? The claim states that more than 225,000 people are dead due to COVID-19.',
#    'Would a faster COVID response in the US reduced the death toll? Due to exponential viral spread, our delay in action was devastating. In the wake of the U.S. response, 117,858 Americans died in the four months following the first 15 confirmed cases. After an equivalent period, Germany suffered only 8,863 casualties. Scaling up the German population of 83.7 million to America’s 331 million, a U.S.-sized Germany would have suffered 35,049 Covid-19 deaths. So if the U.S. had acted as effectively as Germany, 70% of U.S. coronavirus deaths might have been prevented.',
#    'What is 70% of 230,512? 161,358',
#    'Did the claim imply that government actions could have changed the death toll? Yes. The claim suggests that responsible actions could have led to fewer deaths.']},
#  {'claim': 'Why should you pay more taxes than Donald Trump pays? And that’s a fact. $750. Remember what he said when that was raised a while ago, how he only pays … He said, ‘Because I’m smart. I know how to game the system.’',
#   'required_reannotation': False,
#   'label': 'Supported',
#   'justification': 'True, question mark required (?) ',
#   'claim_date': '30-10-2020',
#   'speaker': 'Joe Biden',
#   'original_claim_url': None,
#   'fact_checking_article': 'https://web.archive.org/web/20210212055748/https://www.washingtonpost.com/politics/2020/11/02/fact-checking-final-arguments-biden-trump/',
#   'reporting_source': None,
#   'location_ISO_code': 'US',
#   'claim_types': ['Event/Property Claim'],
#   'fact_checking_strategies': ['Written Evidence'],
#   'questions': [{'question': "What was Trump's tax return in 2017",
#     'answers': [{'answer': 'Trump Paid $750 in Federal Income Taxes in 2017',
#       'answer_type': 'Extractive',
#       'source_url': 'https://web.archive.org/web/20210212182804/https://www.nytimes.com/2020/09/29/us/trump-750-taxes.html',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20210212182804/https://www.nytimes.com/2020/09/29/us/trump-750-taxes.html'}]},
#    {'question': 'Is it true that many Americans feel they pay more taxes than wealthy individuals like Donald Trump?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'Surveys indicate that a significant portion of the population believes the tax system is unfair.'}]},
#    {'question': 'What do critics say about the fairness of the tax system in relation to wealthy individuals?',
#     'answers': [{'answer': 'Critics argue that the tax system allows wealthy individuals to exploit loopholes, leading to lower tax payments.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': 'What was the exact quote from Donald Trump regarding his tax strategy?',
#     'answers': [{'answer': 'He said, ‘Because I’m smart. I know how to game the system.’',
#       'answer_type': 'Extractive',
#       'boolean_explanation': ''}]},
#    {'question': 'When did Trump say he was smart for not paying taxes',
#     'answers': [{'answer': 'He made the boast during the 2016 electoral debate with Hilary Clinton',
#       'answer_type': 'Abstractive',
#       'source_url': 'https://web.archive.org/web/20210212190344/https://www.cnbc.com/2016/09/26/trump-brags-about-not-paying-taxes-that-makes-me-smart.html',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20210212190344/https://www.cnbc.com/2016/09/26/trump-brags-about-not-paying-taxes-that-makes-me-smart.html'}]},
#    {'question': 'Did Donald Trump pay only $750 in federal income taxes for the year 2016?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': "This amount was reported in various news articles discussing Trump's tax returns."}]},
#    {'question': 'What did Donald Trump imply about his tax payments in relation to his intelligence?',
#     'answers': [{'answer': 'He suggested that he pays less because he is smart and knows how to navigate the tax system.',
#       'answer_type': 'Abstractive.',
#       'boolean_explanation': ''}]}],
#   'cached_original_claim_url': None,
#   'gold_evidence': [1, 0, 0, 0, 1, 0, 0],
#   'id': 7,
#   'evidence_txt_list': ["What was Trump's tax return in 2017? Trump Paid $750 in Federal Income Taxes in 2017",
#    'Is it true that many Americans feel they pay more taxes than wealthy individuals like Donald Trump? Yes. Surveys indicate that a significant portion of the population believes the tax system is unfair.',
#    'What do critics say about the fairness of the tax system in relation to wealthy individuals? Critics argue that the tax system allows wealthy individuals to exploit loopholes, leading to lower tax payments.',
#    'What was the exact quote from Donald Trump regarding his tax strategy? He said, ‘Because I’m smart. I know how to game the system.’',
#    'When did Trump say he was smart for not paying taxes? He made the boast during the 2016 electoral debate with Hilary Clinton',
#    "Did Donald Trump pay only $750 in federal income taxes for the year 2016? Yes. This amount was reported in various news articles discussing Trump's tax returns.",
#    'What did Donald Trump imply about his tax payments in relation to his intelligence? He suggested that he pays less because he is smart and knows how to navigate the tax system.']},
#  {'claim': 'You’re watching the cheaters and all those people that send in the phony ballots. … They want to have the count weeks after November 3.',
#   'required_reannotation': False,
#   'label': 'Refuted',
#   'justification': 'The mail in ballots have to be counted no later than 7 days after election day. so that it would be weeks later is refuted. ',
#   'claim_date': '30-10-2020',
#   'speaker': 'Donald Trump',
#   'original_claim_url': None,
#   'fact_checking_article': 'https://web.archive.org/web/20210212055748/https://www.washingtonpost.com/politics/2020/11/02/fact-checking-final-arguments-biden-trump/',
#   'reporting_source': None,
#   'location_ISO_code': 'US',
#   'claim_types': ['Event/Property Claim'],
#   'fact_checking_strategies': ['Written Evidence'],
#   'questions': [{'question': 'When are mail-in ballots counted?',
#     'answers': [{'answer': 'Vote-by-mail ballots that are mailed must be postmarked on or before Election Day and received by your county elections office no later than 7 days after Election Day.',
#       'answer_type': 'Extractive',
#       'source_url': 'https://www.sos.ca.gov/elections/voter-registration/vote-mail',
#       'source_medium': 'Web text',
#       'cached_source_url': 'https://web.archive.org/web/20230324140705/https://www.sos.ca.gov/elections/voter-registration/vote-mail'}]},
#    {'question': 'Is there evidence that the counting of ballots will take weeks after November 3?',
#     'answers': [{'answer': 'No',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'Most states have laws requiring ballots to be counted by a certain deadline.'}]},
#    {'question': 'What do critics say about the timing of ballot counting?',
#     'answers': [{'answer': 'Critics argue that extended counting periods could lead to confusion and mistrust in the electoral process.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': 'What did a local election official say about ballot counting procedures?',
#     'answers': [{'answer': "The official stated, 'We will ensure that every legitimate vote is counted as soon as possible.'",
#       'answer_type': 'Extractive',
#       'boolean_explanation': ''}]},
#    {'question': 'are all non-mail ballots counted by election day?',
#     'answers': [{'answer': 'No',
#       'answer_type': 'Boolean',
#       'source_url': 'https://calmatters.org/politics/california-election-2020/2020/03/california-primary-election-results-delayed/',
#       'source_medium': 'Web text',
#       'boolean_explanation': 'The counting will take time and is not done by the end of election day.',
#       'cached_source_url': 'https://web.archive.org/web/20230324140839/https://calmatters.org/politics/california-election-2020/2020/03/california-primary-election-results-delayed/'}]},
#    {'question': 'Are there reports of people submitting fraudulent ballots?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'There have been isolated incidents reported, but they are not widespread.'}]},
#    {'question': 'What is the general timeline for counting ballots in elections?',
#     'answers': [{'answer': 'Ballots are typically counted on election night, but some states allow counting to continue for days after the election.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]}],
#   'cached_original_claim_url': None,
#   'gold_evidence': [1, 0, 0, 0, 1, 0, 0],
#   'id': 8,
#   'evidence_txt_list': ['When are mail-in ballots counted? Vote-by-mail ballots that are mailed must be postmarked on or before Election Day and received by your county elections office no later than 7 days after Election Day.',
#    'Is there evidence that the counting of ballots will take weeks after November 3? No. Most states have laws requiring ballots to be counted by a certain deadline.',
#    'What do critics say about the timing of ballot counting? Critics argue that extended counting periods could lead to confusion and mistrust in the electoral process.',
#    "What did a local election official say about ballot counting procedures? The official stated, 'We will ensure that every legitimate vote is counted as soon as possible.'",
#    'are all non-mail ballots counted by election day? No. The counting will take time and is not done by the end of election day.',
#    'Are there reports of people submitting fraudulent ballots? Yes. There have been isolated incidents reported, but they are not widespread.',
#    'What is the general timeline for counting ballots in elections? Ballots are typically counted on election night, but some states allow counting to continue for days after the election.']},
#  {'claim': 'You see the number today? 33.1 GDP. The biggest in the history of our country by almost triple, right? Almost triple. Now it’s very much bigger than any GDP we’ve ever had. You have to go back to the 1950s, and then it’s less than half. This is the greatest number, 33.1 percent.',
#   'required_reannotation': True,
#   'label': 'Not Enough Evidence',
#   'justification': 'There is only one question and that is unanswerable. There is no evidence about the GDP in 2020 when the claim was made. Therefore there is not enough evidence to refute or support the claim.',
#   'claim_date': '30-10-2020',
#   'speaker': 'Donald Trump',
#   'original_claim_url': None,
#   'fact_checking_article': 'https://web.archive.org/web/20210212055748/https://www.washingtonpost.com/politics/2020/11/02/fact-checking-final-arguments-biden-trump/',
#   'reporting_source': None,
#   'location_ISO_code': 'US',
#   'claim_types': ['Numerical Claim'],
#   'fact_checking_strategies': ['Written Evidence', 'Numerical Comparison'],
#   'questions': [{'question': "Was 1950's U.S GDP less than half of 2020's GDP of 33.1?",
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'source_url': 'https://www.stlouisfed.org/on-the-economy/2017/april/us-manufacturing-really-declining',
#       'source_medium': 'Image/graphic',
#       'boolean_explanation': '28.1 percent in 1953',
#       'cached_source_url': 'https://web.archive.org/web/20230327113019/https://www.stlouisfed.org/on-the-economy/2017/april/us-manufacturing-really-declining'}]},
#    {'question': 'Has the GDP ever been reported to be less than half of the current figure in the past?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'The claim indicates that previous GDP figures were less than half of the current 33.1%.'}]},
#    {'question': 'What is the significance of the number 33.1% according to the speaker?',
#     'answers': [{'answer': 'The speaker claims it is the greatest number ever recorded for GDP growth.',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]},
#    {'question': 'What does the speaker imply about the GDP growth compared to previous records?',
#     'answers': [{'answer': 'The speaker suggests that the current GDP is almost triple the previous highest records.',
#       'answer_type': 'Extractive',
#       'boolean_explanation': ''}]},
#    {'question': "What was the USA's GDP in the 1950s?",
#     'answers': [{'answer': 'No answer could be found.',
#       'answer_type': 'Unanswerable',
#       'source_url': '',
#       'source_medium': ''}]},
#    {'question': 'Is 33.1% the highest GDP growth rate recorded in the country?',
#     'answers': [{'answer': 'Yes',
#       'answer_type': 'Boolean',
#       'boolean_explanation': 'The claim states that 33.1% is the biggest GDP number in the history of the country.'}]},
#    {'question': 'What historical period does the claim reference for comparison to the current GDP?',
#     'answers': [{'answer': 'The 1950s',
#       'answer_type': 'Abstractive',
#       'boolean_explanation': ''}]}],
#   'cached_original_claim_url': None,
#   'gold_evidence': [1, 0, 0, 0, 1, 0, 0],
#   'id': 9,
#   'evidence_txt_list': ["Was 1950's U.S GDP less than half of 2020's GDP of 33.1? Yes. 28.1 percent in 1953",
#    'Has the GDP ever been reported to be less than half of the current figure in the past? Yes. The claim indicates that previous GDP figures were less than half of the current 33.1%.',
#    'What is the significance of the number 33.1% according to the speaker? The speaker claims it is the greatest number ever recorded for GDP growth.',
#    'What does the speaker imply about the GDP growth compared to previous records? The speaker suggests that the current GDP is almost triple the previous highest records.',
#    "What was the USA's GDP in the 1950s? No answer could be found.",
#    'Is 33.1% the highest GDP growth rate recorded in the country? Yes. The claim states that 33.1% is the biggest GDP number in the history of the country.',
#    'What historical period does the claim reference for comparison to the current GDP? The 1950s']}]
