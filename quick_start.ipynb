# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Quick start for explainable-fact-checking

# %%
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 4.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from sentence_transformers import CrossEncoder
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-1-c24b71707c38> in <cell line: 1>()
# ...

# %%
# !pip install -e '/content/drive/Shareddrives/SoftLab/Projects/Explainable Fact checking EURECOM/code XFC'
# !pip install git+https://github.com/softlab-unimore/fairnesseval@main
# Out:
# Obtaining file:///content/drive/Shareddrives/SoftLab/Projects/Explainable%20Fact%20checking%20EURECOM/code%20XFC
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/Raldir/FEVEROUS (to revision main) to /tmp/pip-install-nb0uqf7h/feverous_ecf68e15cb26474980a7354d09269c91
#   Running command git clone --filter=blob:none --quiet https://github.com/Raldir/FEVEROUS /tmp/pip-install-nb0uqf7h/feverous_ecf68e15cb26474980a7354d09269c91
#   Resolved https://github.com/Raldir/FEVEROUS to commit 3a2610cfe47db1877a56764900d562a59703f2d9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
# ...
#   Using cached transformers-4.26.1-py3-none-any.whl (6.3 MB)
# ...
#   Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# ...

# %%
# !pip install git+https://github.com/Raldir/FEVEROUS@main
# Out:
# ...
#   Cloning https://github.com/Raldir/FEVEROUS (to revision main) to /tmp/pip-req-build-8de8n3q0
#   Running command git clone --filter=blob:none --quiet https://github.com/Raldir/FEVEROUS /tmp/pip-req-build-8de8n3q0
#   Resolved https://github.com/Raldir/FEVEROUS to commit 3a2610cfe47db1877a56764900d562a59703f2d9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 39.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 63.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 58.0 MB/s eta 0:00:00
# ...

# %%
import sys
# !pip install -U scikit-learn

# %%
sys.path.append('/content/drive/Shareddrives/SoftLab/Projects/Explainable Fact checking EURECOM/code XFC')

# %%
import explainable_fact_checking as xfc
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-4-155960251762> in <cell line: 1>()
# ----> 1 import explainable_fact_checking as xfc
#
# /content/drive/Shareddrives/SoftLab/Projects/Explainable Fact checking EURECOM/code XFC/explainable_fact_checking/__init__.py in <module>
#       3 from .explanation_presentation import style_exp_to_html, style_single_exp_list
#       4 from .explanations_load import load_explanations_lime_to_df, explanation_to_dict_olap, explanations_to_df_lime, load_explanations_lime
# ----> 5 from .adapters.feverous_model import FeverousModelAdapter
#       6 from . import models
# ...
